# %% [markdown]
# ## Processing pipeline
# Start with a zip file and:
#  - Unzip it
#  - For each file inside it
#    - ODV Parse it
#    - Filter it or what not
#    - append to parsed list
#    - Combine with metadata pulled from other places
#    - Create columns specifically for DwC
#  - Merge parsed list into single DF
#  - write to DwC
#    - Take column matching dictionaries
#    - Rename columns to match DwC standards
#    - Write to CSV

# %%
# Std
import zipfile
import pathlib
import os
# NonStd
import dask.dataframe as ddf
import pandas as pd
# Custom
import pyodv

# %% [markdown]
# ### Vars and paths

# %%
input_zip = './input/order_60837_1.zip'
temp_folder = './temp/'
output_dwc = './output/'

# %% [markdown]
# ### Unzip
# Input:
#   - Zipped file path
#   - Location to unzip to
#
# Output
#   - Unzipped files in folder

# %%
zipped_path = pathlib.Path(input_zip)
file_name = zipped_path.stem
unzipped_path = pathlib.Path(temp_folder).joinpath(file_name)

with zipfile.ZipFile(input_zip, 'r') as zip_ref:
    zip_ref.extractall(unzipped_path)

# %% [markdown]
# ### Parse and Merge files
# Input:
#   - Unzipped dir
# Output:
#   - Parsed and merged dataframe object.

# %%
config = {'occurrenceStatus_hardcode': 'present'}

odv_list  = []
df_list = [] 
ref_list = []
for filename in os.listdir(unzipped_path):
    f = os.path.join(unzipped_path, filename)
    # checking if it is a file
    if os.path.isfile(f):
        try:
            print(f'===== {f} =====')
            parsed_file = pyodv.ODV_Struct(f) 
            odv_list.append(parsed_file) 
            ref_list.append(parsed_file.refs[0])
            this_df = pd.concat([parsed_file.df_data, parsed_file.df_var],axis=1)
            this_df['scope'] = parsed_file.refs[0]['@sdn:scope']
            this_df['defined_by'] = parsed_file.refs[0]['@xlink:href']
            this_df['occurrenceStatus'] = config.get('occurrenceStatus_hardcode', 'present')
            
            df_list.append(this_df)
        except Exception as err:
            print(err)
            print('==============================================================')
# Out:
# ===== temp/order_60837_1/000729_BODV_Bent_138791_V1.txt =====
# --Problem Parsing Refs--
# syntax error: line 1, column 0
# SeaDataNet ODV   - Generated by Replication Manager 1.0.51 (with Octopus 1.7.1) - 2022-04-05 12:34:50+0200
# Has 13 params
# Has 1 refs.
# Good file shape
# ===== temp/order_60837_1/000729_BODV_Bent_137824_V1.txt =====
# --Problem Parsing Refs--
# syntax error: line 1, column 0
# SeaDataNet ODV   - Generated by Replication Manager 1.0.51 (with Octopus 1.7.1) - 2022-04-05 12:29:54+0200
# Has 13 params
# Has 1 refs.
# Good file shape
# ===== temp/order_60837_1/000729_BODV_Bent_131628_V1.txt =====
# --Problem Parsing Refs--
# syntax error: line 1, column 0
# SeaDataNet ODV   - Generated by Replication Manager 1.0.51 (with Octopus 1.7.1) - 2022-04-05 12:30:42+0200
# Has 13 params
# Has 1 refs.
# Good file shape
# ===== temp/order_60837_1/000729_BODV_Bent_133214_V1.txt =====
# --Problem Parsing Refs--
# syntax error: line 1, column 0
# SeaDataNet ODV   - Generated by Replication Manager 1.0.51 (with Octopus 1.7.1) - 2022-04-05 12:24:20+0200
# Has 13 params
# Has 1 refs.
# Good file shape
# ===== temp/order_60837_1/000729_BODV_Bent_131442_V1.txt =====
# --Problem Parsing Refs--
# syntax error: line 1, column 0
# SeaDataNet ODV   - Generated by Replication Manager 1.0.51 (with Octopus 1.7.1) - 2022-04-05 12:26:38+0200
# Has 13 params
# Has 1 refs.
# Good file shape
# ===== temp/order_60837_1/000729_BODV_Bent_142229_V1.txt =====
# --Problem Parsing Refs--
# syntax error: line 1, column 0
# SeaDataNet ODV   - Generated by Replication Manager 1.0.51 (with Octopus 1.7.1) - 2022-04-05 12:23:47+0200
# Has 13 params
# Has 1 refs.
# Good file shape
# ===== temp/order_60837_1/000729_BODV_Bent_133903_V1.txt =====
# --Problem Parsing Refs--
# syntax error: line 1, column 0
# SeaDataNet ODV   - Generated by Replication Manager 1.0.51 (with Octopus 1.7.1) - 2022-04-05 12:36:42+0200
# Has 13 params
# Has 1 refs.
# Good file shape
# ===== temp/order_60837_1/000729_BODV_Bent_138229_V1.txt =====
# --Problem Parsing Refs--
# syntax error: line 1, column 0
# SeaDataNet ODV   - Generated by Replication Manager 1.0.51 (with Octopus 1.7.1) - 2022-04-05 12:21:04+0200
# Has 13 params
# Has 1 refs.
# Good file shape
# ===== temp/order_60837_1/000729_BODV_Bent_133071_V1.txt =====
# --Problem Parsing Refs--
# syntax error: line 1, column 0
# SeaDataNet ODV   - Generated by Replication Manager 1.0.51 (with Octopus 1.7.1) - 2022-04-05 12:14:35+0200
# Has 13 params
# Has 1 refs.
# Good file shape
# ===== temp/order_60837_1/000729_BODV_Bent_133338_V1.txt =====
# --Problem Parsing Refs--
# syntax error: line 1, column 0
# SeaDataNet ODV   - Generated by Replication Manager 1.0.51 (with Octopus 1.7.1) - 2022-04-05 12:25:36+0200
# Has 13 params
# Has 1 refs.
# Good file shape
# ===== temp/order_60837_1/000729_BODV_Bent_140011_V1.txt =====
# --Problem Parsing Refs--
# syntax error: line 1, column 0
# SeaDataNet ODV   - Generated by Replication Manager 1.0.51 (with Octopus 1.7.1) - 2022-04-05 12:36:25+0200
# Has 13 params
# Has 1 refs.
# Good file shape
# ===== temp/order_60837_1/000729_BODV_Bent_133707_V1.txt =====
# --Problem Parsing Refs--
# syntax error: line 1, column 0
# SeaDataNet ODV   - Generated by Replication Manager 1.0.51 (with Octopus 1.7.1) - 2022-04-05 12:35:51+0200
# Has 13 params
# Has 1 refs.
# Good file shape
# ===== temp/order_60837_1/000729_BODV_Bent_133150_V1.txt =====
# --Problem Parsing Refs--
# syntax error: line 1, column 0
# SeaDataNet ODV   - Generated by Replication Manager 1.0.51 (with Octopus 1.7.1) - 2022-04-05 12:13:45+0200
# Has 13 params
# Has 1 refs.
# Good file shape
# ===== temp/order_60837_1/000729_BODV_Bent_140087_V1.txt =====
# --Problem Parsing Refs--
# syntax error: line 1, column 0
# SeaDataNet ODV   - Generated by Replication Manager 1.0.51 (with Octopus 1.7.1) - 2022-04-05 12:31:42+0200
# Has 13 params
# Has 1 refs.
# Good file shape
# ===== temp/order_60837_1/000729_BODV_Bent_138436_V1.txt =====
# --Problem Parsing Refs--
# syntax error: line 1, column 0
# SeaDataNet ODV   - Generated by Replication Manager 1.0.51 (with Octopus 1.7.1) - 2022-04-05 12:32:15+0200
# Has 13 params
# Has 1 refs.
# Good file shape
# ===== temp/order_60837_1/000729_BODV_Bent_139937_V1.txt =====
# --Problem Parsing Refs--
# syntax error: line 1, column 0
# SeaDataNet ODV   - Generated by Replication Manager 1.0.51 (with Octopus 1.7.1) - 2022-04-05 12:20:45+0200
# Has 13 params
# Has 1 refs.
# Good file shape
# ===== temp/order_60837_1/000729_BODV_Bent_138389_V1.txt =====
# --Problem Parsing Refs--
# syntax error: line 1, column 0
# SeaDataNet ODV   - Generated by Replication Manager 1.0.51 (with Octopus 1.7.1) - 2022-04-05 12:12:33+0200
# Has 13 params
# Has 1 refs.
# Good file shape
# ===== temp/order_60837_1/000729_BODV_Bent_138839_V1.txt =====
# --Problem Parsing Refs--
# syntax error: line 1, column 0
# SeaDataNet ODV   - Generated by Replication Manager 1.0.51 (with Octopus 1.7.1) - 2022-04-05 12:19:12+0200
# Has 13 params
# Has 1 refs.
# Good file shape
# ===== temp/order_60837_1/000729_BODV_Bent_139959_V1.txt =====
# --Problem Parsing Refs--
# syntax error: line 1, column 0
# SeaDataNet ODV   - Generated by Replication Manager 1.0.51 (with Octopus 1.7.1) - 2022-04-05 12:27:53+0200
# Has 13 params
# Has 1 refs.
# Good file shape
# ===== temp/order_60837_1/000729_BODV_Bent_133922_V1.txt =====
# --Problem Parsing Refs--
# syntax error: line 1, column 0
# SeaDataNet ODV   - Generated by Replication Manager 1.0.51 (with Octopus 1.7.1) - 2022-04-05 12:25:56+0200
# Has 13 params
# Has 1 refs.
# Good file shape
# ===== temp/order_60837_1/000729_BODV_Bent_131848_V1.txt =====
# --Problem Parsing Refs--
# syntax error: line 1, column 0
# SeaDataNet ODV   - Generated by Replication Manager 1.0.51 (with Octopus 1.7.1) - 2022-04-05 12:35:15+0200
# Has 13 params
# Has 1 refs.
# Good file shape
# ===== temp/order_60837_1/000729_BODV_Bent_141438_V1.txt =====
# --Problem Parsing Refs--
# syntax error: line 1, column 0
# SeaDataNet ODV   - Generated by Replication Manager 1.0.51 (with Octopus 1.7.1) - 2022-04-05 12:16:08+0200
# Has 13 params
# Has 1 refs.
# Good file shape
# ===== temp/order_60837_1/000729_BODV_Bent_133168_V1.txt =====
# --Problem Parsing Refs--
# syntax error: line 1, column 0
# SeaDataNet ODV   - Generated by Replication Manager 1.0.51 (with Octopus 1.7.1) - 2022-04-05 12:30:07+0200
# Has 13 params
# Has 1 refs.
# Good file shape
# ===== temp/order_60837_1/000729_BODV_Bent_138641_V1.txt =====
# --Problem Parsing Refs--
# syntax error: line 1, column 0
# SeaDataNet ODV   - Generated by Replication Manager 1.0.51 (with Octopus 1.7.1) - 2022-04-05 12:17:44+0200
# Has 13 params
# Has 1 refs.
# Good file shape
# ===== temp/order_60837_1/000729_BODV_Bent_139979_V1.txt =====
# --Problem Parsing Refs--
# syntax error: line 1, column 0
# SeaDataNet ODV   - Generated by Replication Manager 1.0.51 (with Octopus 1.7.1) - 2022-04-05 12:36:43+0200
# Has 13 params
# Has 1 refs.
# Good file shape
# ===== temp/order_60837_1/000729_BODV_Bent_132279_V1.txt =====
# --Problem Parsing Refs--
# syntax error: line 1, column 0
# SeaDataNet ODV   - Generated by Replication Manager 1.0.51 (with Octopus 1.7.1) - 2022-04-05 12:23:38+0200
# Has 13 params
# Has 1 refs.
# Good file shape
# ===== temp/order_60837_1/000729_BODV_Bent_132446_V1.txt =====
# --Problem Parsing Refs--
# syntax error: line 1, column 0
# SeaDataNet ODV   - Generated by Replication Manager 1.0.51 (with Octopus 1.7.1) - 2022-04-05 12:15:08+0200
# Has 13 params
# Has 1 refs.
# Good file shape
# ===== temp/order_60837_1/000729_BODV_Bent_130976_V1.txt =====
# --Problem Parsing Refs--
# syntax error: line 1, column 0
# SeaDataNet ODV   - Generated by Replication Manager 1.0.51 (with Octopus 1.7.1) - 2022-04-05 12:36:30+0200
# Has 13 params
# Has 1 refs.
# Good file shape
# ===== temp/order_60837_1/000729_BODV_Bent_138719_V1.txt =====
# --Problem Parsing Refs--
# syntax error: line 1, column 0
# SeaDataNet ODV   - Generated by Replication Manager 1.0.51 (with Octopus 1.7.1) - 2022-04-05 12:17:25+0200
# Has 13 params
# Has 1 refs.
# Good file shape
# ===== temp/order_60837_1/000729_BODV_Bent_137697_V1.txt =====
# --Problem Parsing Refs--
# syntax error: line 1, column 0
# SeaDataNet ODV   - Generated by Replication Manager 1.0.51 (with Octopus 1.7.1) - 2022-04-05 12:15:18+0200
# Has 13 params
# Has 1 refs.
# Good file shape
# ===== temp/order_60837_1/000729_BODV_Bent_139771_V1.txt =====
# --Problem Parsing Refs--
# syntax error: line 1, column 0
# SeaDataNet ODV   - Generated by Replication Manager 1.0.51 (with Octopus 1.7.1) - 2022-04-05 12:19:27+0200
# Has 13 params
# Has 1 refs.
# Good file shape
# ===== temp/order_60837_1/000729_BODV_Bent_135936_V1.txt =====
# --Problem Parsing Refs--
# syntax error: line 1, column 0
# SeaDataNet ODV   - Generated by Replication Manager 1.0.51 (with Octopus 1.7.1) - 2022-04-05 12:25:06+0200
# Has 13 params
# Has 1 refs.
# Good file shape
# ===== temp/order_60837_1/000729_BODV_Bent_142442_V1.txt =====
# --Problem Parsing Refs--
# syntax error: line 1, column 0
# SeaDataNet ODV   - Generated by Replication Manager 1.0.51 (with Octopus 1.7.1) - 2022-04-05 12:16:46+0200
# Has 13 params
# Has 1 refs.
# Good file shape
# ===== temp/order_60837_1/000729_BODV_Bent_141348_V1.txt =====
# --Problem Parsing Refs--
# syntax error: line 1, column 0
# SeaDataNet ODV   - Generated by Replication Manager 1.0.51 (with Octopus 1.7.1) - 2022-04-05 12:14:34+0200
# Has 13 params
# Has 1 refs.
# Good file shape
# ===== temp/order_60837_1/000729_BODV_Bent_131894_V1.txt =====
# --Problem Parsing Refs--
# syntax error: line 1, column 0
# SeaDataNet ODV   - Generated by Replication Manager 1.0.51 (with Octopus 1.7.1) - 2022-04-05 12:25:14+0200
# Has 13 params
# Has 1 refs.
# Good file shape
# ===== temp/order_60837_1/000729_BODV_Bent_130719_V1.txt =====
# --Problem Parsing Refs--
# syntax error: line 1, column 0
# SeaDataNet ODV   - Generated by Replication Manager 1.0.51 (with Octopus 1.7.1) - 2022-04-05 12:33:52+0200
# Has 13 params
# Has 1 refs.
# Good file shape
# ===== temp/order_60837_1/000729_BODV_Bent_131055_V1.txt =====
# --Problem Parsing Refs--
# syntax error: line 1, column 0
# SeaDataNet ODV   - Generated by Replication Manager 1.0.51 (with Octopus 1.7.1) - 2022-04-05 12:28:03+0200
# Has 13 params
# Has 1 refs.
# Good file shape
# ===== temp/order_60837_1/000729_BODV_Bent_138682_V1.txt =====
# --Problem Parsing Refs--
# syntax error: line 1, column 0
# SeaDataNet ODV   - Generated by Replication Manager 1.0.51 (with Octopus 1.7.1) - 2022-04-05 12:18:14+0200
# Has 13 params
# Has 1 refs.
# Good file shape
# ===== temp/order_60837_1/000729_BODV_Bent_130046_V1.txt =====
# --Problem Parsing Refs--
# syntax error: line 1, column 0
# SeaDataNet ODV   - Generated by Replication Manager 1.0.51 (with Octopus 1.7.1) - 2022-04-05 12:35:48+0200
# Has 13 params
# Has 1 refs.
# Good file shape
# ===== temp/order_60837_1/000729_BODV_Bent_141255_V1.txt =====
# --Problem Parsing Refs--
# syntax error: line 1, column 0
# SeaDataNet ODV   - Generated by Replication Manager 1.0.51 (with Octopus 1.7.1) - 2022-04-05 12:31:00+0200
# Has 13 params
# Has 1 refs.
# Good file shape
# ===== temp/order_60837_1/000729_BODV_Bent_129981_V1.txt =====
# --Problem Parsing Refs--
# syntax error: line 1, column 0
# SeaDataNet ODV   - Generated by Replication Manager 1.0.51 (with Octopus 1.7.1) - 2022-04-05 12:22:06+0200
# Has 13 params
# Has 1 refs.
# Good file shape
# ===== temp/order_60837_1/000729_BODV_Bent_131801_V1.txt =====
# --Problem Parsing Refs--
# syntax error: line 1, column 0
# SeaDataNet ODV   - Generated by Replication Manager 1.0.51 (with Octopus 1.7.1) - 2022-04-05 12:32:49+0200
# Has 13 params
# Has 1 refs.
# Good file shape
# ===== temp/order_60837_1/000729_BODV_Bent_138098_V1.txt =====
# --Problem Parsing Refs--
# syntax error: line 1, column 0
# SeaDataNet ODV   - Generated by Replication Manager 1.0.51 (with Octopus 1.7.1) - 2022-04-05 12:21:08+0200
# Has 13 params
# Has 1 refs.
# Good file shape
# ===== temp/order_60837_1/000729_BODV_Bent_131383_V1.txt =====
# 'utf-8' codec can't decode byte 0xf6 in position 15767: invalid start byte
# ==============================================================
# ===== temp/order_60837_1/000729_BODV_Bent_138018_V1.txt =====
# --Problem Parsing Refs--
# syntax error: line 1, column 0
# SeaDataNet ODV   - Generated by Replication Manager 1.0.51 (with Octopus 1.7.1) - 2022-04-05 12:34:57+0200
# Has 13 params
# Has 1 refs.
# Good file shape
# ===== temp/order_60837_1/000729_BODV_Bent_131923_V1.txt =====
# --Problem Parsing Refs--
# syntax error: line 1, column 0
# SeaDataNet ODV   - Generated by Replication Manager 1.0.51 (with Octopus 1.7.1) - 2022-04-05 12:31:46+0200
# Has 13 params
# Has 1 refs.
# Good file shape
# ===== temp/order_60837_1/000729_BODV_Bent_142073_V1.txt =====
# --Problem Parsing Refs--
# syntax error: line 1, column 0
# SeaDataNet ODV   - Generated by Replication Manager 1.0.51 (with Octopus 1.7.1) - 2022-04-05 12:16:21+0200
# Has 13 params
# Has 1 refs.
# Good file shape
# ===== temp/order_60837_1/000729_BODV_Bent_132552_V1.txt =====
# --Problem Parsing Refs--
# syntax error: line 1, column 0
# SeaDataNet ODV   - Generated by Replication Manager 1.0.51 (with Octopus 1.7.1) - 2022-04-05 12:15:24+0200
# Has 13 params
# Has 1 refs.
# Good file shape
# ===== temp/order_60837_1/000729_BODV_Bent_142227_V1.txt =====
# --Problem Parsing Refs--
# syntax error: line 1, column 0
# SeaDataNet ODV   - Generated by Replication Manager 1.0.51 (with Octopus 1.7.1) - 2022-04-05 12:17:48+0200
# Has 13 params
# Has 1 refs.
# Good file shape
# ===== temp/order_60837_1/000729_BODV_Bent_129833_V1.txt =====
# --Problem Parsing Refs--
# syntax error: line 1, column 0
# SeaDataNet ODV   - Generated by Replication Manager 1.0.51 (with Octopus 1.7.1) - 2022-04-05 12:19:41+0200
# Has 13 params
# Has 1 refs.
# Good file shape
# ===== temp/order_60837_1/000729_BODV_Bent_130983_V1.txt =====
# --Problem Parsing Refs--
# syntax error: line 1, column 0
# SeaDataNet ODV   - Generated by Replication Manager 1.0.51 (with Octopus 1.7.1) - 2022-04-05 12:19:27+0200
# Has 13 params
# Has 1 refs.
# Good file shape
# ===== temp/order_60837_1/000729_BODV_Bent_132654_V1.txt =====
# --Problem Parsing Refs--
# syntax error: line 1, column 0
# SeaDataNet ODV   - Generated by Replication Manager 1.0.51 (with Octopus 1.7.1) - 2022-04-05 12:13:45+0200
# Has 13 params
# Has 1 refs.
# Good file shape
# ===== temp/order_60837_1/000729_BODV_Bent_130617_V1.txt =====
# --Problem Parsing Refs--
# syntax error: line 1, column 0
# SeaDataNet ODV   - Generated by Replication Manager 1.0.51 (with Octopus 1.7.1) - 2022-04-05 12:27:16+0200
# Has 13 params
# Has 1 refs.
# Good file shape
# ===== temp/order_60837_1/000729_BODV_Bent_133712_V1.txt =====
# --Problem Parsing Refs--
# syntax error: line 1, column 0
# SeaDataNet ODV   - Generated by Replication Manager 1.0.51 (with Octopus 1.7.1) - 2022-04-05 12:23:22+0200
# Has 13 params
# Has 1 refs.
# Good file shape
# ===== temp/order_60837_1/000729_BODV_Bent_142053_V1.txt =====
# --Problem Parsing Refs--
# syntax error: line 1, column 0
# SeaDataNet ODV   - Generated by Replication Manager 1.0.51 (with Octopus 1.7.1) - 2022-04-05 12:37:00+0200
# Has 13 params
# Has 1 refs.
# Good file shape
# ===== temp/order_60837_1/000729_BODV_Bent_131818_V1.txt =====
# --Problem Parsing Refs--
# syntax error: line 1, column 0
# SeaDataNet ODV   - Generated by Replication Manager 1.0.51 (with Octopus 1.7.1) - 2022-04-05 12:15:53+0200
# Has 13 params
# Has 1 refs.
# Good file shape
# ===== temp/order_60837_1/000729_BODV_Bent_130318_V1.txt =====
# --Problem Parsing Refs--
# syntax error: line 1, column 0
# SeaDataNet ODV   - Generated by Replication Manager 1.0.51 (with Octopus 1.7.1) - 2022-04-05 12:30:41+0200
# Has 13 params
# Has 1 refs.
# Good file shape
# ===== temp/order_60837_1/000729_BODV_Bent_132601_V1.txt =====
# --Problem Parsing Refs--
# syntax error: line 1, column 0
# SeaDataNet ODV   - Generated by Replication Manager 1.0.51 (with Octopus 1.7.1) - 2022-04-05 12:13:42+0200
# Has 13 params
# Has 1 refs.
# Good file shape
# ===== temp/order_60837_1/000729_BODV_Bent_142326_V1.txt =====
# --Problem Parsing Refs--
# syntax error: line 1, column 0
# SeaDataNet ODV   - Generated by Replication Manager 1.0.51 (with Octopus 1.7.1) - 2022-04-05 12:33:57+0200
# Has 13 params
# Has 1 refs.
# Good file shape
# ===== temp/order_60837_1/000729_BODV_Bent_131064_V1.txt =====
# --Problem Parsing Refs--
# syntax error: line 1, column 0
# SeaDataNet ODV   - Generated by Replication Manager 1.0.51 (with Octopus 1.7.1) - 2022-04-05 12:21:18+0200
# Has 13 params
# Has 1 refs.
# Good file shape
# ===== temp/order_60837_1/000729_BODV_Bent_138895_V1.txt =====
# --Problem Parsing Refs--
# syntax error: line 1, column 0
# SeaDataNet ODV   - Generated by Replication Manager 1.0.51 (with Octopus 1.7.1) - 2022-04-05 12:28:30+0200
# Has 13 params
# Has 1 refs.
# Good file shape
# ===== temp/order_60837_1/000729_BODV_Bent_130576_V1.txt =====
# --Problem Parsing Refs--
# syntax error: line 1, column 0
# SeaDataNet ODV   - Generated by Replication Manager 1.0.51 (with Octopus 1.7.1) - 2022-04-05 12:34:19+0200
# Has 13 params
# Has 1 refs.
# Good file shape
# ===== temp/order_60837_1/000729_BODV_Bent_136110_V1.txt =====
# --Problem Parsing Refs--
# syntax error: line 1, column 0
# SeaDataNet ODV   - Generated by Replication Manager 1.0.51 (with Octopus 1.7.1) - 2022-04-05 12:17:46+0200
# Has 13 params
# Has 1 refs.
# Good file shape
# ===== temp/order_60837_1/000729_BODV_Bent_140544_V1.txt =====
# --Problem Parsing Refs--
# syntax error: line 1, column 0
# SeaDataNet ODV   - Generated by Replication Manager 1.0.51 (with Octopus 1.7.1) - 2022-04-05 12:30:59+0200
# Has 13 params
# Has 1 refs.
# Good file shape
# ===== temp/order_60837_1/000729_BODV_Bent_140838_V1.txt =====
# --Problem Parsing Refs--
# syntax error: line 1, column 0
# SeaDataNet ODV   - Generated by Replication Manager 1.0.51 (with Octopus 1.7.1) - 2022-04-05 12:20:43+0200
# Has 13 params
# Has 1 refs.
# Good file shape
# ===== temp/order_60837_1/000729_BODV_Bent_137725_V1.txt =====
# --Problem Parsing Refs--
# syntax error: line 1, column 0
# SeaDataNet ODV   - Generated by Replication Manager 1.0.51 (with Octopus 1.7.1) - 2022-04-05 12:18:59+0200
# Has 13 params
# Has 1 refs.
# Good file shape
# ===== temp/order_60837_1/000729_BODV_Bent_131539_V1.txt =====
# --Problem Parsing Refs--
# syntax error: line 1, column 0
# SeaDataNet ODV   - Generated by Replication Manager 1.0.51 (with Octopus 1.7.1) - 2022-04-05 12:15:14+0200
# Has 13 params
# Has 1 refs.
# Good file shape
# ===== temp/order_60837_1/000729_BODV_Bent_140179_V1.txt =====
# --Problem Parsing Refs--
# syntax error: line 1, column 0
# SeaDataNet ODV   - Generated by Replication Manager 1.0.51 (with Octopus 1.7.1) - 2022-04-05 12:31:00+0200
# Has 13 params
# Has 1 refs.
# Good file shape
# ===== temp/order_60837_1/data.csv =====
# list index out of range
# ==============================================================
# ===== temp/order_60837_1/000729_BODV_Bent_130592_V1.txt =====
# --Problem Parsing Refs--
# syntax error: line 1, column 0
# SeaDataNet ODV   - Generated by Replication Manager 1.0.51 (with Octopus 1.7.1) - 2022-04-05 12:28:09+0200
# Has 13 params
# Has 1 refs.
# Good file shape
# ===== temp/order_60837_1/000729_BODV_Bent_139358_V1.txt =====
# --Problem Parsing Refs--
# syntax error: line 1, column 0
# SeaDataNet ODV   - Generated by Replication Manager 1.0.51 (with Octopus 1.7.1) - 2022-04-05 12:28:27+0200
# Has 13 params
# Has 1 refs.
# Good file shape
# ===== temp/order_60837_1/000729_BODV_Bent_138626_V1.txt =====
# --Problem Parsing Refs--
# syntax error: line 1, column 0
# SeaDataNet ODV   - Generated by Replication Manager 1.0.51 (with Octopus 1.7.1) - 2022-04-05 12:17:11+0200
# Has 13 params
# Has 1 refs.
# Good file shape
# ===== temp/order_60837_1/000729_BODV_Bent_141959_V1.txt =====
# --Problem Parsing Refs--
# syntax error: line 1, column 0
# SeaDataNet ODV   - Generated by Replication Manager 1.0.51 (with Octopus 1.7.1) - 2022-04-05 12:26:50+0200
# Has 13 params
# Has 1 refs.
# Good file shape
# ===== temp/order_60837_1/000729_BODV_Bent_130493_V1.txt =====
# --Problem Parsing Refs--
# syntax error: line 1, column 0
# SeaDataNet ODV   - Generated by Replication Manager 1.0.51 (with Octopus 1.7.1) - 2022-04-05 12:35:11+0200
# Has 13 params
# Has 1 refs.
# Good file shape
# ===== temp/order_60837_1/000729_BODV_Bent_133359_V1.txt =====
# --Problem Parsing Refs--
# syntax error: line 1, column 0
# SeaDataNet ODV   - Generated by Replication Manager 1.0.51 (with Octopus 1.7.1) - 2022-04-05 12:29:26+0200
# Has 13 params
# Has 1 refs.
# Good file shape
# ===== temp/order_60837_1/000729_BODV_Bent_141936_V1.txt =====
# --Problem Parsing Refs--
# syntax error: line 1, column 0
# SeaDataNet ODV   - Generated by Replication Manager 1.0.51 (with Octopus 1.7.1) - 2022-04-05 12:30:09+0200
# Has 13 params
# Has 1 refs.
# Good file shape
# ===== temp/order_60837_1/000729_BODV_Bent_132725_V1.txt =====
# --Problem Parsing Refs--
# syntax error: line 1, column 0
# SeaDataNet ODV   - Generated by Replication Manager 1.0.51 (with Octopus 1.7.1) - 2022-04-05 12:29:52+0200
# Has 13 params
# Has 1 refs.
# Good file shape
# ===== temp/order_60837_1/000729_BODV_Bent_129866_V1.txt =====
# --Problem Parsing Refs--
# syntax error: line 1, column 0
# SeaDataNet ODV   - Generated by Replication Manager 1.0.51 (with Octopus 1.7.1) - 2022-04-05 12:28:51+0200
# Has 13 params
# Has 1 refs.
# Good file shape
# ===== temp/order_60837_1/000729_BODV_Bent_138840_V1.txt =====
# --Problem Parsing Refs--
# syntax error: line 1, column 0
# SeaDataNet ODV   - Generated by Replication Manager 1.0.51 (with Octopus 1.7.1) - 2022-04-05 12:20:33+0200
# Has 13 params
# Has 1 refs.
# Good file shape
# ===== temp/order_60837_1/000729_BODV_Bent_130800_V1.txt =====
# --Problem Parsing Refs--
# syntax error: line 1, column 0
# SeaDataNet ODV   - Generated by Replication Manager 1.0.51 (with Octopus 1.7.1) - 2022-04-05 12:31:38+0200
# Has 13 params
# Has 1 refs.
# Good file shape
# ===== temp/order_60837_1/000729_BODV_Bent_139028_V1.txt =====
# --Problem Parsing Refs--
# syntax error: line 1, column 0
# SeaDataNet ODV   - Generated by Replication Manager 1.0.51 (with Octopus 1.7.1) - 2022-04-05 12:31:45+0200
# Has 13 params
# Has 1 refs.
# Good file shape
# ===== temp/order_60837_1/000729_BODV_Bent_131959_V1.txt =====
# --Problem Parsing Refs--
# syntax error: line 1, column 0
# SeaDataNet ODV   - Generated by Replication Manager 1.0.51 (with Octopus 1.7.1) - 2022-04-05 12:11:58+0200
# Has 13 params
# Has 1 refs.
# Good file shape
# ===== temp/order_60837_1/000729_BODV_Bent_138851_V1.txt =====
# --Problem Parsing Refs--
# syntax error: line 1, column 0
# SeaDataNet ODV   - Generated by Replication Manager 1.0.51 (with Octopus 1.7.1) - 2022-04-05 12:24:45+0200
# Has 13 params
# Has 1 refs.
# Good file shape
# ===== temp/order_60837_1/000729_BODV_Bent_137987_V1.txt =====
# --Problem Parsing Refs--
# syntax error: line 1, column 0
# SeaDataNet ODV   - Generated by Replication Manager 1.0.51 (with Octopus 1.7.1) - 2022-04-05 12:36:02+0200
# Has 13 params
# Has 1 refs.
# Good file shape
# ===== temp/order_60837_1/000729_BODV_Bent_139707_V1.txt =====
# --Problem Parsing Refs--
# syntax error: line 1, column 0
# SeaDataNet ODV   - Generated by Replication Manager 1.0.51 (with Octopus 1.7.1) - 2022-04-05 12:34:33+0200
# Has 13 params
# Has 1 refs.
# Good file shape
# ===== temp/order_60837_1/000729_BODV_Bent_131307_V1.txt =====
# --Problem Parsing Refs--
# syntax error: line 1, column 0
# SeaDataNet ODV   - Generated by Replication Manager 1.0.51 (with Octopus 1.7.1) - 2022-04-05 12:15:21+0200
# Has 13 params
# Has 1 refs.
# Good file shape
# ===== temp/order_60837_1/000729_BODV_Bent_139415_V1.txt =====
# --Problem Parsing Refs--
# syntax error: line 1, column 0
# SeaDataNet ODV   - Generated by Replication Manager 1.0.51 (with Octopus 1.7.1) - 2022-04-05 12:19:32+0200
# Has 13 params
# Has 1 refs.
# Good file shape
# ===== temp/order_60837_1/000729_BODV_Bent_140300_V1.txt =====
# --Problem Parsing Refs--
# syntax error: line 1, column 0
# SeaDataNet ODV   - Generated by Replication Manager 1.0.51 (with Octopus 1.7.1) - 2022-04-05 12:22:16+0200
# Has 13 params
# Has 1 refs.
# Good file shape
# ===== temp/order_60837_1/000729_BODV_Bent_141728_V1.txt =====
# --Problem Parsing Refs--
# syntax error: line 1, column 0
# SeaDataNet ODV   - Generated by Replication Manager 1.0.51 (with Octopus 1.7.1) - 2022-04-05 12:19:04+0200
# Has 13 params
# Has 1 refs.
# Good file shape
# ===== temp/order_60837_1/000729_BODV_Bent_139001_V1.txt =====
# --Problem Parsing Refs--
# syntax error: line 1, column 0
# SeaDataNet ODV   - Generated by Replication Manager 1.0.51 (with Octopus 1.7.1) - 2022-04-05 12:12:09+0200
# Has 13 params
# Has 1 refs.
# Good file shape
# ===== temp/order_60837_1/000729_BODV_Bent_138139_V1.txt =====
# --Problem Parsing Refs--
# syntax error: line 1, column 0
# SeaDataNet ODV   - Generated by Replication Manager 1.0.51 (with Octopus 1.7.1) - 2022-04-05 12:12:37+0200
# Has 13 params
# Has 1 refs.
# Good file shape
# ===== temp/order_60837_1/000729_BODV_Bent_141035_V1.txt =====
# --Problem Parsing Refs--
# syntax error: line 1, column 0
# SeaDataNet ODV   - Generated by Replication Manager 1.0.51 (with Octopus 1.7.1) - 2022-04-05 12:20:17+0200
# Has 13 params
# Has 1 refs.
# Good file shape
# ===== temp/order_60837_1/000729_BODV_Bent_141083_V1.txt =====
# --Problem Parsing Refs--
# syntax error: line 1, column 0
# SeaDataNet ODV   - Generated by Replication Manager 1.0.51 (with Octopus 1.7.1) - 2022-04-05 12:34:42+0200
# Has 13 params
# Has 1 refs.
# Good file shape
# ===== temp/order_60837_1/000729_BODV_Bent_140000_V1.txt =====
# --Problem Parsing Refs--
# syntax error: line 1, column 0
# SeaDataNet ODV   - Generated by Replication Manager 1.0.51 (with Octopus 1.7.1) - 2022-04-05 12:29:05+0200
# Has 13 params
# Has 1 refs.
# Good file shape
# ===== temp/order_60837_1/000729_BODV_Bent_140463_V1.txt =====
# --Problem Parsing Refs--
# syntax error: line 1, column 0
# SeaDataNet ODV   - Generated by Replication Manager 1.0.51 (with Octopus 1.7.1) - 2022-04-05 12:11:58+0200
# Has 13 params
# Has 1 refs.
# Good file shape
# ===== temp/order_60837_1/000729_BODV_Bent_138634_V1.txt =====
# --Problem Parsing Refs--
# syntax error: line 1, column 0
# SeaDataNet ODV   - Generated by Replication Manager 1.0.51 (with Octopus 1.7.1) - 2022-04-05 12:36:01+0200
# Has 13 params
# Has 1 refs.
# Good file shape
# ===== temp/order_60837_1/000729_BODV_Bent_140791_V1.txt =====
# --Problem Parsing Refs--
# syntax error: line 1, column 0
# SeaDataNet ODV   - Generated by Replication Manager 1.0.51 (with Octopus 1.7.1) - 2022-04-05 12:21:46+0200
# Has 13 params
# Has 1 refs.
# Good file shape
# ===== temp/order_60837_1/000729_BODV_Bent_131008_V1.txt =====
# --Problem Parsing Refs--
# syntax error: line 1, column 0
# SeaDataNet ODV   - Generated by Replication Manager 1.0.51 (with Octopus 1.7.1) - 2022-04-05 12:14:10+0200
# Has 13 params
# Has 1 refs.
# Good file shape
# ===== temp/order_60837_1/000729_BODV_Bent_142157_V1.txt =====
# --Problem Parsing Refs--
# syntax error: line 1, column 0
# SeaDataNet ODV   - Generated by Replication Manager 1.0.51 (with Octopus 1.7.1) - 2022-04-05 12:17:10+0200
# Has 13 params
# Has 1 refs.
# Good file shape
# ===== temp/order_60837_1/000729_BODV_Bent_136211_V1.txt =====
# --Problem Parsing Refs--
# syntax error: line 1, column 0
# SeaDataNet ODV   - Generated by Replication Manager 1.0.51 (with Octopus 1.7.1) - 2022-04-05 12:20:57+0200
# Has 13 params
# Has 1 refs.
# Good file shape
# ===== temp/order_60837_1/000729_BODV_Bent_137951_V1.txt =====
# --Problem Parsing Refs--
# syntax error: line 1, column 0
# SeaDataNet ODV   - Generated by Replication Manager 1.0.51 (with Octopus 1.7.1) - 2022-04-05 12:26:53+0200
# Has 13 params
# Has 1 refs.
# Good file shape

# %%
metadata_path = os.path.join(unzipped_path, 'data.csv')
metadata_df = pd.read_csv(metadata_path)
metadata_df['LOCAL_CDI_ID_split'] = metadata_df['LOCAL_CDI_ID'].str.split(pat="/").str[0]
merged_df = pd.concat(df_list, axis=0) 
merged_df = merged_df.join(metadata_df.set_index('LOCAL_CDI_ID_split'), on='LOCAL_CDI_ID', how='left', rsuffix = '_meta')
merged_df.reset_index(level=None, drop=True, inplace = True)

# %%
pd.set_option("display.max_columns", None)
merged_df.head()
# Out:
#     Cruise   Station  Bot. Depth [m] LOCAL_CDI_ID  yyyy-mm-ddThh:mm:ss.sss  \
# 0  unknown  LISD0025             NaN  Bent_138791  1997-04-22T00:00:00.000
# 1  unknown  LISD0025             NaN  Bent_138791  1997-04-22T00:00:00.000
# 2  unknown  LISD0025             NaN  Bent_138791  1997-04-22T00:00:00.000
# 3  unknown  LISD0025             NaN  Bent_138791  1997-04-22T00:00:00.000
# 4  unknown  LISD0025             NaN  Bent_138791  1997-04-22T00:00:00.000
#
#   Type  Longitude [degrees_east]  EDMO_code  Latitude [degrees_north]  \
# 0    *                    8.5661      729.0                   55.0934
# 1    *                    8.5661      729.0                   55.0934
# 2    *                    8.5661      729.0                   55.0934
# 3    *                    8.5661      729.0                   55.0934
# 4    *                    8.5661      729.0                   55.0934
#
#    MinimumObservationDepth [m]  MaximumObservationDepth [m]  SampleID [#]  \
# 0                          0.0                          0.0         31147
# 1                          0.0                          0.0         31148
# 2                          0.0                          0.0         31149
# 3                          0.0                          0.0         31150
# 4                          0.0                          0.0         31151
#
#    SamplingEffort [m^2]  SubsampleID [#]  SubSamplingCoefficient [none]  \
# 0                0.0079              NaN                            NaN
# 1                0.0079              NaN                            NaN
# 2                0.0079              NaN                            NaN
# 3                0.0079              NaN                            NaN
# 4                0.0079              NaN                            NaN
#
#   ScientificName [none]                       ScientificNameID [#] Sex [none]  \
# 0          Hydrobia sp.  urn:lsid:marinespecies.org:taxname:138081          U
# 1          Hydrobia sp.  urn:lsid:marinespecies.org:taxname:138081          U
# 2          Hydrobia sp.  urn:lsid:marinespecies.org:taxname:138081          U
# 3          Hydrobia sp.  urn:lsid:marinespecies.org:taxname:138081          U
# 4          Hydrobia sp.  urn:lsid:marinespecies.org:taxname:138081          U
#
#   LifeStage [none]  ObservedIndividualCount [#]  WWBiom_Samp_BE007117 [g]  \
# 0                U                         20.0                       NaN
# 1                U                         17.0                       NaN
# 2                U                         28.0                       NaN
# 3                U                         50.0                       NaN
# 4                U                         63.0                       NaN
#
#    DWBiom_Samp_BE007117 [g]            scope  \
# 0                       NaN  729:Bent_138791
# 1                       NaN  729:Bent_138791
# 2                       NaN  729:Bent_138791
# 3                       NaN  729:Bent_138791
# 4                       NaN  729:Bent_138791
#
#                                           defined_by occurrenceStatus  \
# 0  https://cdi.seadatanet.org/report/edmo/729/Ben...          present
# 1  https://cdi.seadatanet.org/report/edmo/729/Ben...          present
# 2  https://cdi.seadatanet.org/report/edmo/729/Ben...          present
# 3  https://cdi.seadatanet.org/report/edmo/729/Ben...          present
# 4  https://cdi.seadatanet.org/report/edmo/729/Ben...          present
#
#        Data Set name                                         Discipline  \
# 0  Benthosset_138791  Biological oceanography (DS01)|Marine geology ...
# 1  Benthosset_138791  Biological oceanography (DS01)|Marine geology ...
# 2  Benthosset_138791  Biological oceanography (DS01)|Marine geology ...
# 3  Benthosset_138791  Biological oceanography (DS01)|Marine geology ...
# 4  Benthosset_138791  Biological oceanography (DS01)|Marine geology ...
#
#                                             Category  \
# 0  Other biological measurements (B027)|Rock and ...
# 1  Other biological measurements (B027)|Rock and ...
# 2  Other biological measurements (B027)|Rock and ...
# 3  Other biological measurements (B027)|Rock and ...
# 4  Other biological measurements (B027)|Rock and ...
#
#                                   Variables measured Data format  \
# 0  Reference numbers (ACYC)|Sampling parameters (...        bodv
# 1  Reference numbers (ACYC)|Sampling parameters (...        bodv
# 2  Reference numbers (ACYC)|Sampling parameters (...        bodv
# 3  Reference numbers (ACYC)|Sampling parameters (...        bodv
# 4  Reference numbers (ACYC)|Sampling parameters (...        bodv
#
#    Data format version  Data size  Data Set creation Date  Latitude 1  \
# 0                  0.4       5227                20220405      8.5661
# 1                  0.4       5227                20220405      8.5661
# 2                  0.4       5227                20220405      8.5661
# 3                  0.4       5227                20220405      8.5661
# 4                  0.4       5227                20220405      8.5661
#
#    Latitude 2  Longitude 1  Longitude 2                            Datum  \
# 0      8.5661    55.093399    55.093403  World Geodetic System 84 (4326)
# 1      8.5661    55.093399    55.093403  World Geodetic System 84 (4326)
# 2      8.5661    55.093399    55.093403  World Geodetic System 84 (4326)
# 3      8.5661    55.093399    55.093403  World Geodetic System 84 (4326)
# 4      8.5661    55.093399    55.093403  World Geodetic System 84 (4326)
#
#   Measuring area type  Water depth (m)                 Depth reference  \
# 0         point (004)            0.287  Lowest Astronomical Tide (D01)
# 1         point (004)            0.287  Lowest Astronomical Tide (D01)
# 2         point (004)            0.287  Lowest Astronomical Tide (D01)
# 3         point (004)            0.287  Lowest Astronomical Tide (D01)
# 4         point (004)            0.287  Lowest Astronomical Tide (D01)
#
#    Minimum instrument depth (m)  Maximum instrument depth (m)  Start Date  \
# 0                           NaN                           NaN    19970422
# 1                           NaN                           NaN    19970422
# 2                           NaN                           NaN    19970422
# 3                           NaN                           NaN    19970422
# 4                           NaN                           NaN    19970422
#
#   Start time  End Date  End time  Vertical resolution  \
# 0   00:00:00  19970422  00:00:00                  NaN
# 1   00:00:00  19970422  00:00:00                  NaN
# 2   00:00:00  19970422  00:00:00                  NaN
# 3   00:00:00  19970422  00:00:00                  NaN
# 4   00:00:00  19970422  00:00:00                  NaN
#
#    Vertical resolution unit Instrument / gear type  Track resolution  \
# 0                       NaN  benthos samplers (24)               NaN
# 1                       NaN  benthos samplers (24)               NaN
# 2                       NaN  benthos samplers (24)               NaN
# 3                       NaN  benthos samplers (24)               NaN
# 4                       NaN  benthos samplers (24)               NaN
#
#    Track resolution unit  Frequency  Frequency unit         Platform type  \
# 0                    NaN        NaN             NaN  research vessel (31)
# 1                    NaN        NaN             NaN  research vessel (31)
# 2                    NaN        NaN             NaN  research vessel (31)
# 3                    NaN        NaN             NaN  research vessel (31)
# 4                    NaN        NaN             NaN  research vessel (31)
#
#    Cruise name  Alternative cruise name  Cruise start Date Station name  \
# 0          NaN                      NaN                NaN     LISD0025
# 1          NaN                      NaN                NaN     LISD0025
# 2          NaN                      NaN                NaN     LISD0025
# 3          NaN                      NaN                NaN     LISD0025
# 4          NaN                      NaN                NaN     LISD0025
#
#   Alternative station name  Station start Date  \
# 0                 LISD0025            19800505
# 1                 LISD0025            19800505
# 2                 LISD0025            19800505
# 3                 LISD0025            19800505
# 4                 LISD0025            19800505
#
#                                           Originator  \
# 0  Aarhus University, Department of Bioscience, M...
# 1  Aarhus University, Department of Bioscience, M...
# 2  Aarhus University, Department of Bioscience, M...
# 3  Aarhus University, Department of Bioscience, M...
# 4  Aarhus University, Department of Bioscience, M...
#
#                                  Data Holding centre  Project name  \
# 0  Aarhus University, Department of Bioscience, M...           NaN
# 1  Aarhus University, Department of Bioscience, M...           NaN
# 2  Aarhus University, Department of Bioscience, M...           NaN
# 3  Aarhus University, Department of Bioscience, M...           NaN
# 4  Aarhus University, Department of Bioscience, M...           NaN
#
#    Project type                                   EDMED references  \
# 0           NaN  Time series of zoobenthos in Danish waters (19...
# 1           NaN  Time series of zoobenthos in Danish waters (19...
# 2           NaN  Time series of zoobenthos in Danish waters (19...
# 3           NaN  Time series of zoobenthos in Danish waters (19...
# 4           NaN  Time series of zoobenthos in Danish waters (19...
#
#    CSR references  CSR platform name  CSR platform code  \
# 0             NaN                NaN                NaN
# 1             NaN                NaN                NaN
# 2             NaN                NaN                NaN
# 3             NaN                NaN                NaN
# 4             NaN                NaN                NaN
#
#    Publication references                                   Data Distributor  \
# 0                     NaN  Aarhus University,Danish Centre for Environmen...
# 1                     NaN  Aarhus University,Danish Centre for Environmen...
# 2                     NaN  Aarhus University,Danish Centre for Environmen...
# 3                     NaN  Aarhus University,Danish Centre for Environmen...
# 4                     NaN  Aarhus University,Danish Centre for Environmen...
#
#    Database reference            Access/ordering of data  \
# 0                 NaN  web data access with registration
# 1                 NaN  web data access with registration
# 2                 NaN  web data access with registration
# 3                 NaN  web data access with registration
# 4                 NaN  web data access with registration
#
#                                   Access restriction  \
# 0  Creative Commons Attribution 4.0 International...
# 1  Creative Commons Attribution 4.0 International...
# 2  Creative Commons Attribution 4.0 International...
# 3  Creative Commons Attribution 4.0 International...
# 4  Creative Commons Attribution 4.0 International...
#
#    CDI-record creation date  CDI-record id LOCAL_CDI_ID_meta  \
# 0                  20220405        2049364    Bent_138791/v1
# 1                  20220405        2049364    Bent_138791/v1
# 2                  20220405        2049364    Bent_138791/v1
# 3                  20220405        2049364    Bent_138791/v1
# 4                  20220405        2049364    Bent_138791/v1
#
#                                          CDI-partner
# 0  Aarhus University, Department of Bioscience, M...
# 1  Aarhus University, Department of Bioscience, M...
# 2  Aarhus University, Department of Bioscience, M...
# 3  Aarhus University, Department of Bioscience, M...
# 4  Aarhus University, Department of Bioscience, M...

# %% [markdown]
# ### Write to DwC
# When writing to DwC archive there are a couple of xml files created, a folder with the data in it and then it's all zipped.
#
# Taking a look here: https://ipt.gbif.org/manual/en/ipt/2.5/dwca-guide#publishing-dwc-a-manually
#
# Steps required are:
#   - Prepare data files
#   - Create a Metafile
#   - Create a metadata file (eml.xml)
#   - Ensure the data files, the metafile (meta.xml) and metadata file (eml.xml) are in the same directory or folder. Compress the folder using one of the support compression formats. The result is a DwC-A.

# %%
event_mapping = {
        'eventID':'SampleID [#]',
        'eventDate':'yyyy-mm-ddThh:mm:ss.sss',
        'decimalLatitude':'Latitude [degrees_north]',
        'decimalLongitude':'Longitude [degrees_east]',
        'institutionCode':'EDMO_code',
        'datasetName':'Data Set name',
        'maximumDepthInMeters':'MinimumObservationDepth [m]',
        'minimumDepthInMeters':'MaximumObservationDepth [m]',
        'coordinateUncertaintyInMeters':None,
        'footprintWKT':None,
        'type':None,
        'parenEventID':None,
        'dataGeneralizations':None,
        'eventRemarks':None,
        'samplingProtocol':None,
        'locationID':'Station',
        'locality':None,
        'locationRemarks':None,
        }

# %%
occ_mapping = {}

# %%
emof_mapping = {}

# %%
def odv_dwc_mapping(df, map_dict):
    dwc_col_list = []
    for dwc_colname, odv_colname in map_dict.items():
        if odv_colname is not None:
            try:
                dwc_col = df[odv_colname]
                dwc_col.name = dwc_colname
                dwc_col_list.append(dwc_col)
            except Exception as err:
                print(err)
    mapped_df = pd.concat(dwc_col_list, axis=1)
    return mapped_df

# %%
dwc_event = odv_dwc_mapping(merged_df, event_mapping)
# dwc_occ = odv_dwc_mapping(merged_df, event_mapping)

# %%
dwc_event
# Out:
#       eventID                eventDate  decimalLatitude  decimalLongitude  \
# 0       31147  1997-04-22T00:00:00.000          55.0934            8.5661
# 1       31148  1997-04-22T00:00:00.000          55.0934            8.5661
# 2       31149  1997-04-22T00:00:00.000          55.0934            8.5661
# 3       31150  1997-04-22T00:00:00.000          55.0934            8.5661
# 4       31151  1997-04-22T00:00:00.000          55.0934            8.5661
# ...       ...                      ...              ...               ...
# 2921    28448  2002-09-09T00:00:00.000          55.1826            8.5902
# 2922    28446  2002-09-09T00:00:00.000          55.1826            8.5902
# 2923    28448  2002-09-09T00:00:00.000          55.1826            8.5902
# 2924    28444  2002-09-09T00:00:00.000          55.1826            8.5902
# 2925    28448  2002-09-09T00:00:00.000          55.1826            8.5902
#
#       institutionCode        datasetName  maximumDepthInMeters  \
# 0               729.0  Benthosset_138791                   0.0
# 1               729.0  Benthosset_138791                   0.0
# 2               729.0  Benthosset_138791                   0.0
# 3               729.0  Benthosset_138791                   0.0
# 4               729.0  Benthosset_138791                   0.0
# ...               ...                ...                   ...
# 2921            729.0  Benthosset_137951                   0.0
# 2922            729.0  Benthosset_137951                   0.0
# 2923            729.0  Benthosset_137951                   0.0
# 2924            729.0  Benthosset_137951                   0.0
# 2925            729.0  Benthosset_137951                   0.0
#
#       minimumDepthInMeters locationID
# 0                      0.0   LISD0025
# 1                      0.0   LISD0025
# 2                      0.0   LISD0025
# 3                      0.0   LISD0025
# 4                      0.0   LISD0025
# ...                    ...        ...
# 2921                   0.0   JUVD0011
# 2922                   0.0   JUVD0011
# 2923                   0.0   JUVD0011
# 2924                   0.0   JUVD0011
# 2925                   0.0   JUVD0011
#
# [2926 rows x 9 columns]
