# %% [markdown]
# ## Processing pipeline
# Start with a zip file and:
#  - Unzip it
#  - For each file inside it
#    - ODV Parse it
#    - Filter it or what not
#    - append to parsed list
#    - Combine with metadata pulled from other places
#    - Create columns specifically for DwC
#  - Merge parsed list into single DF
#  - write to DwC
#    - Take column matching dictionaries
#    - Rename columns to match DwC standards
#    - Write to CSV

# %%
# ! pip install --upgrade --force-reinstall scipy
# ! pip install pymsteams
# ! pip install pyodv
# ! pip install --upgrade --force-reinstall git+https://github.com/vliz-be-opsci/pyodv/

# %%
# Std
import zipfile
import pathlib
import os
import re

# NonStd
import dask.dataframe as ddf
import numpy as np
import pandas as pd
import geopy.distance
import itertools
import requests
import json
import pymsteams
import uuid
from functools import cache
from itertools import chain

# Custom
import pyodv

import logging
log = logging.getLogger('main') 
log.setLevel(logging.DEBUG)


pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# ### Vars and paths

# %% [markdown]
# ### The code running in the docker container
#
# Below the code from the app directory is imported. Changes there will require this to be reimported.

# %%
event_mapping = {
        'eventID':['eventID'],
        'eventDate':['yyyy-mm-ddThh:mm:ss.sss', 'YYYY-MM-DDThh:mm:ss.sss'],
        'parentEventID':['parentEventID'],
        'decimalLatitude':['Latitude'],
        'decimalLongitude':['Longitude'],
        'institutionCode':['Originator','institutionCode','EDMO_code'],
        'datasetName':['EDMED references'],
        'maximumDepthInMeters':['MaximumObservationDepth'],
        'minimumDepthInMeters':['MinimumObservationDepth'],
        'coordinateUncertaintyInMeters':['CoordinateUncertaintyInMeters'],
        'footprintWKT':['footprint_wkt'], # How to put in a single value into table? Shouldn't this be metadata?
        'type':[None],
        'parenEventID':[None],
        'dataGeneralizations':[None],
        'eventRemarks':[None],
        'samplingProtocol':['Samplingprotocol', 'SamplingProtocol'],
        'locationID':['Station'],
        'locality':['locality','Station name','Alternative station name'],
        'locationRemarks':[None],
        }

occ_mapping = {
            'eventID': ['eventID'],
            'occurrenceID': ['occurrenceID'],
            'basisOfRecord': ['basisOfRecord'],
            'occurrenceStatus': ['occurrenceStatus'], # Hardcoded? 
            'scientificName': ['ScientificName'], # Must have trailing space
            'scientificNameID': ['ScientificNameID'], 
            }   

def odv_to_dwc(job_dict):
    '''
    The actual function that does the conversions from 
    the ODV zip into the DwC
    '''
    odv_zip = job_dict.get('last_data_file')
    odv_meta = job_dict.get('last_data_file')
    if odv_zip is None:
        log.warning('No ODV file provided...')
        return None

    log.info(f'===Converting {odv_zip} to DwC===')
    folder_dict = create_folder_structure(odv_zip)
    unzip(folder_dict)
    parsed_df, odv_list = parse_odv(folder_dict)

    # Create new IDs
    # ==================
    log.debug('   -Building WKT...')
    applied_df = parsed_df.apply(lambda row: create_wkt(row), axis='columns', result_type='expand')
    applied_df = applied_df.rename(columns={0: 'CoordinateUncertaintyInMeters', 1: 'footprint_wkt'})
    parsed_df  = pd.concat([parsed_df, applied_df], axis='columns')
    
    log.debug('   -Creating Event and Occurrence IDs...')
    df_id = parsed_df.apply(lambda row: create_IDs(row), axis='columns', result_type='expand')
    df_id = df_id.rename(columns={0: 'eventID', 1: 'occurrenceID', 2: 'parentEventID'})
    parsed_df  = pd.concat([parsed_df, df_id], axis='columns')
    
    parsed_df = create_new_columns(parsed_df)
    parsed_df = rename_odv_columns(parsed_df)
    
    # Create EventCore File
    dwc_event = odv_dwc_mapping(parsed_df, event_mapping) 
    dwc_event.to_csv(folder_dict.get('event_path'), index = False)

    # Create OccCore File
    dwc_occ = odv_dwc_mapping(parsed_df, occ_mapping)
    dwc_occ.to_csv(folder_dict.get('occ_path'), index = False)

    # Create EMOF from Occ data
    params = convert_params_to_df(odv_list)
    dwc_emof = emof_gen(parsed_df, params)
    dwc_emof = emof_cleanup(dwc_emof, occ_mapping, event_mapping)

    # Create EMOF from Event data
    # dwc_emof = create_emof_df()
    # dwc_emof.to_csv(folder_dict.get('emof_path'))

    # Create Metadata File
    # params = convert_params_to_df()
    # dwc_occ = <some function>
    # dwc_emof.to_json(folder_dict.get('meta_path'))

    # Dump all data
    parsed_df.to_csv(folder_dict.get('all_data_path'), index = False)

    log.info(f'===Finished converting {odv_zip} to DwC===')

    return parsed_df
 
def create_new_columns(parsed_df):
    # Create new columns
    # ==================
    parsed_df['occurrenceStatus'] = parsed_df.apply(lambda row: find_occurrenceStatus(row), axis='columns', result_type='expand')
    parsed_df['basisOfRecord'] = parsed_df.apply(lambda row: find_basisOfRecord(row), axis='columns', result_type='expand')
    if 'EDMO_code' in parsed_df.columns:
        parsed_df['institutionCode'] = 'EDMO:' + parsed_df['EDMO_code'].astype(str)

    if ('Station name' in parsed_df.columns) and ('Alternative station name' in parsed_df.columns):
        parsed_df['locality'] = parsed_df['Station name'].astype(str) + '_' + parsed_df['Alternative station name'].astype(str)
    # =================
    return parsed_df

def create_folder_structure(odv_zip):
    '''
    Create a directory structure next to the odv_zip file:
    > <some-file>.zip
    > ./meta.zip
        
    > ./<some-file>/unzip
    > ./<some-file>/unzip/odv1.csv, odv2.csv ...

    > ./<some-file>/dwc
    > ./<some-file>/dwc/occ.csv
    > ./<some-file>/dwc/event.csv
    > ./<some-file>/dwc/emof.csv
    '''
    log.debug(f'Creating folder structure for {odv_zip}...')
    zipped_path = pathlib.Path(odv_zip).parent 
    meta_zipped_path = zipped_path.joinpath('meta.zip')

    unzip_folder = pathlib.Path(zipped_path).joinpath('unzip')
    unzip_folder.mkdir(parents=True, exist_ok=True)

    meta_file = pathlib.Path(odv_zip).stem + '.csv'
    meta_path = unzip_folder.joinpath(meta_file)
    
    dwc_folder = pathlib.Path(zipped_path).joinpath('dwc')
    dwc_folder.mkdir(parents=True, exist_ok=True)
    
    event_file = pathlib.Path(zipped_path).joinpath('dwc').joinpath('event.csv')
    occ_file = pathlib.Path(zipped_path).joinpath('dwc').joinpath('occ.csv')
    emof_file = pathlib.Path(zipped_path).joinpath('dwc').joinpath('emof.csv')
    all_file = pathlib.Path(zipped_path).joinpath('dwc').joinpath('all.csv')

    folder_dict = {'odv_zip': odv_zip,
                   'meta_zip': meta_zipped_path,
                   'unzip_folder': unzip_folder,
                   'dwc_path': dwc_folder,
                   'meta_path': meta_path,
                   'occ_path': occ_file,
                   'emof_path': emof_file,
                   'event_path': event_file,
                   'all_data_path': all_file}

    return folder_dict

def unzip(folder_dict):
    '''
    Unzips the ODV file into the unzip folder
    '''
    log.debug(f"Unzipping file {folder_dict.get('odv_zip')} into {folder_dict.get('unzip_folder')}...")
    with zipfile.ZipFile(folder_dict.get('odv_zip'), 'r') as zip_ref:
        zip_ref.extractall(folder_dict.get('unzip_folder'))
    
    log.debug(f"Unzipping Metadata file {folder_dict.get('meta_zip')} into {folder_dict.get('unzip_folder')}...")
    with zipfile.ZipFile(folder_dict.get('meta_zip'), 'r') as zip_ref:
        zip_ref.extractall(folder_dict.get('unzip_folder'))

    return 

def parse_odv(folder_dict):
    '''
    Parse all the ODV files in the unzipped path into 
    a single data object.
    '''
    unzipped_path = folder_dict.get('unzip_folder')
    meta_path = folder_dict.get('meta_path')

    log.debug(f'Parsing files in {unzipped_path}...')
    config = {'occurrenceStatus_hardcode': 'present'}

    odv_list  = []
    df_list = [] 
    ref_list = []
    for filename in os.listdir(unzipped_path):
        
        f = os.path.join(unzipped_path, filename)
        # checking if it is a file
        if os.path.isfile(f):
            try:
                log.debug(f'===== {f} =====')
                parsed_file = pyodv.ODV_Struct(f) 
                odv_list.append(parsed_file) 
                ref_list.append(parsed_file.refs[0])
                this_df = pd.concat([parsed_file.df_data, parsed_file.df_var],axis=1)
                this_df['scope'] = parsed_file.refs[0]['@sdn:scope'].split(':')[-1]
                this_df['defined_by'] = parsed_file.refs[0]['@xlink:href']
    #             this_df['occurrenceStatus'] = config.get('occurrenceStatus_hardcode', 'present')
                df_list.append(this_df)
            except Exception as err:
                log.debug(err)

    metadata_path =  meta_path
    try:
        log.debug(f'Reading metadata file: {metadata_path}...')
        metadata_df = pd.read_csv(metadata_path)
        metadata_df['LOCAL_CDI_ID_split'] = metadata_df['LOCAL_CDI_ID'].str.split(pat="/").str[0]
    except:
        log.warning('Problem with reading metadata file!')
        metadata_df = pd.DataFrame()

    merged_df = pd.concat(df_list, axis=0) 
    merged_df = merged_df.join(metadata_df.set_index('LOCAL_CDI_ID_split'), on='LOCAL_CDI_ID', how='left', rsuffix = '_meta')
    merged_df.reset_index(level=None, drop=True, inplace = True)
    return merged_df, odv_list

def create_IDs(row):
    '''
    Create EventID and OccurrenceID. 
    Both are a concatenation of the other columns. They also become the columns to join on in the Occurance Table
    and Event table. 
    '''
    if 'yyyy-mm-ddThh:mm:ss.sss' in row.index:
        eventID = str(row['LOCAL_CDI_ID']) + '_' + str(row['Station']) + '_' + str(row['yyyy-mm-ddThh:mm:ss.sss'])
    elif 'YYYY-MM-DDThh:mm:ss.sss' in row.index:
        eventID = str(row['LOCAL_CDI_ID']) + '_' + str(row['Station']) + '_' + str(row['YYYY-MM-DDThh:mm:ss.sss'])
    
    try:  
        scinameID_col = [i for i in row.index if i.startswith('ScientificNameID')] 
        sciname_col = [i for i in row.index if i.startswith('ScientificName ')] 
        if pd.isnull(row[scinameID_col[0]]):
            aphia_id = row[sciname_col[0]].replace(' ','_')
        else:
            aphia_id = re.findall(r"\d{1,}$", row[scinameID_col[0]])[0]
    except Exception as err:
        print(print(row))
        print(err)
    subsamples = [i for i in row.index if i.startswith('SubsampleID')] 
    sample = [i for i in row.index if i.startswith('SampleID')] 
    if len(subsamples) == 0:
        occurrenceID = str(row[sample[0]]) + '_' + str(aphia_id)
    else:
        occurrenceID = str(row[sample[0]]) + '_' + str(row[subsamples[0]]) + '_' + str(aphia_id)
    
    parentEventID = row['LOCAL_CDI_ID']
    
    return eventID, occurrenceID, parentEventID
    
def create_wkt(row):
    '''
    Create WKT from the dataset for each row
    Uses Latitude 1,Latitude 2,Longitude 1,Longitude 2 
    from metadata. Must return uncertainty in meters. 
    '''
    
    try:
        max_lat = max(row['Latitude 1'], row['Latitude 2'])
        min_lat = min(row['Latitude 1'], row['Latitude 2'])
        max_lon = max(row['Longitude 1'], row['Longitude 2'])
        min_lon = min(row['Longitude 1'], row['Longitude 2'])
        bounding_wkt = f"POLYGON (({min_lon} {min_lat}, {min_lon} {max_lat}, {max_lon} {max_lat}, {max_lon} {min_lat}, {min_lon} {min_lat}))"
        
        lat_c = (max_lat + min_lat)/2
        lon_c = (max_lon + min_lon)/2
        
        coord_uncertainty = geopy.distance.geodesic((min_lon, min_lat), (lon_c, lat_c)).m 
          
    except Exception as err:
        print(err)
        bounding_wkt = None
        coord_uncertainty = None
        
    return coord_uncertainty, bounding_wkt


def find_occurrenceStatus(row):
    '''
    Do some kind of occurenceStatus thing.
    '''
    return 'present'


def find_basisOfRecord(row):
    '''
    Do something to create BasisOfRecord. Was 
    '''
    return 'MaterialSample'

@cache
def get_units_from_nerc(measurementUnitID):
    '''
    Get the english units from the nerc vocab
    server. 
    ''' 
    log.debug('   -Downloading vocab from NERC')
    # nerc_uri = row['measurementUnitID']
    nerc_uri = measurementUnitID
    xx = requests.get(nerc_uri + '?_profile=nvs&_mediatype=application/ld+json')
    alt_labels = json.loads(xx.content)['altLabel']
    if isinstance(alt_labels, list):
        for x in alt_labels:
            if isinstance(x, str):
                alt_label = x
    elif isinstance(alt_labels, str):
        alt_label = alt_labels
    else:
        alt_label = 'Unknown'
        log.warning(f'Failure to handle Label: {alt_labels}')
    return alt_label

def convert_params_to_df(odv_list):    
    '''
    Convert the ODV Params into Nerc URI's in order to get them 
    closer towards EMOF. 
    '''
    log.debug('   -Converting ODV params to dataframe...')
    odv_params_list = []
    for odv_obj in odv_list:
        # Loop through ODV items and get the symantic params per file source.     
        xx = [x | odv_obj.refs[0] for x in odv_obj.params]
        odv_params_list.append(xx)

    params_df =  pd.DataFrame(list(chain.from_iterable(odv_params_list))).drop_duplicates()
    # Create a "scope" variable which pretty much allows all other dataframes to join based on file source. 
    params_df['scope'] = params_df['@sdn:scope'].str.split(':').str[-1]
    params_df['measurementType'] = params_df['subject'].apply(lambda x: x.split(':')[-1]) 
    params_df['measurementUnitID'] = params_df['units'].apply(lambda x: f"https://vocab.nerc.ac.uk/collection/P06/current/{x.split('::')[-1]}/")
    params_df['measurementTypeID'] = params_df['object'].apply(lambda x: f"https://vocab.nerc.ac.uk/collection/P01/current/{x.split('::')[-1]}/")
    params_df['measurementUnit'] = params_df.apply(lambda x: get_units_from_nerc(x['measurementUnitID']), axis=1)
    
    return params_df

def rename_odv_columns(df):
    '''
    Rename the ODV dataframe by
      - Strip anything between square brackets: 'Latitude [degrees_north]' >> 'Latitude'
      - Remove the ':INDEXED_TEXT' text in ODV column names. 
      - Run Mapping from ODV names to DwC names: 'Longitude [degrees_east]' >> Longitude >> decimalLongitude
    Mapping should be from a list of possible ODV terms to a single DwC term. Gonna be tough to do...
    '''
    log.debug('   -Renaming ODV column names...')
    old_columns = df.columns
    new_columns = [re.sub(r'\s\[[^>]+?\]|\b:INDEXED_TEXT\b', '', x) or x for x in df.columns]
    rename_dict = dict(zip(old_columns, new_columns))
    df = df.rename(columns = rename_dict)
    return  df

def odv_dwc_mapping(df, map_dict):
    '''
    Take mapping dict and create a new DF that has columns with <map_dict key> as names taken from 
    old_df <map_dict values>.
    
    dwc_name : [odv_colname1, odv_colname2 ...] 
    '''
    log.debug('   -Mapping column names...')
        
    dwc_col_list = []
    rename_dict = {}
    for dwc_colname, odv_colname_list in map_dict.items():
        for odv_colname in odv_colname_list:
            if odv_colname is not None:
                this_column = ''
                try: 
                    this_column = odv_colname
                    dwc_col = df[this_column]
                    dwc_col.name = dwc_colname
                    rename_dict[odv_colname] = dwc_colname
                    dwc_col_list.append(dwc_col)
                    #Take the first match and move on...
                    break
                except Exception as err:
                    log.debug(f'KeyError: Changing {this_column} column to {dwc_colname} but failed.')
                    
    mapped_df = pd.concat(dwc_col_list, axis=1)
#     log.warning(rename_dict)
    mapped_df = mapped_df.rename(columns=rename_dict, errors="ignore")
    return mapped_df

def emof_gen(in_df, in_emof_df):
    '''
    Create EMOF table from the emof_params. 
    Loops through each 
    '''
    log.debug('   -Generating EMOF file...')
    out_df = pd.DataFrame()
    emof_subsets = []
    for index, row in in_emof_df.iterrows():
        scope = row['scope']
        measurementType = row['measurementType']
        df_subset = in_df[(in_df[measurementType].notna()) & (in_df['scope'] == scope)][['eventID','occurrenceID','parentEventID',measurementType]]
        if not df_subset.empty: 
            emof_subset = df_subset.copy()
            emof_subset['measurementID'] = [uuid.uuid4() for _ in range(len(emof_subset.index))]
            emof_subset['measurementValue'] = emof_subset[measurementType]
            emof_subset['measurementValueID'] = None
            emof_subset['measurementType'] = measurementType
            emof_subset['measurementTypeID'] = row['measurementTypeID']
            emof_subset['measurementUnit'] = row['measurementUnit']
            emof_subset['measurementUnitID'] = row['measurementUnitID']
            emof_subset = emof_subset[['eventID',
                                       'occurrenceID',
                                       'parentEventID',
                                       'measurementID',
                                       'measurementValue',
                                       'measurementValueID',
                                       'measurementType',
                                       'measurementTypeID',
                                       'measurementUnit',
                                       'measurementUnitID']]
            emof_subsets.append(emof_subset)

            if 'instrument' in row.index and pd.notna(row.instrument):
                # This row has tool information           
                emof_tool_subset = df_subset.copy()
                instrument_uri = f"http://vocab.nerc.ac.uk/collection/L22/current/{row['instrument'].split('::')[-1]}/"
                emof_tool_subset['measurementID'] = None
                emof_tool_subset['measurementType'] = 'instrument'
                emof_tool_subset['measurementTypeID'] = 'http://vocab.nerc.ac.uk/collection/L19/current/SDNKG01/'
                emof_tool_subset['measurementValue'] = get_units_from_nerc(instrument_uri)
                emof_tool_subset['measurementValueID'] = instrument_uri
                emof_tool_subset['measurementUnit'] = 'Dmnless'
                emof_tool_subset['measurementUnitID'] = 'https://vocab.nerc.ac.uk/collection/P06/current/UUUU/'
                emof_tool_subset['occurrenceID'] = None
                emof_tool_subset = emof_tool_subset[['eventID',
                                                     'occurrenceID',
                                                     'parentEventID',
                                                     'measurementID',
                                                     'measurementValue',
                                                     'measurementValueID',
                                                     'measurementType',
                                                     'measurementTypeID',
                                                     'measurementUnit',
                                                     'measurementUnitID']]
                emof_subsets.append(emof_tool_subset)
    # out_df = out_df[['eventID','occurrenceID','measurementID','measurementValue','measurementValueID','measurementType','measurementTypeID','measurementUnit','measurementUnitID']]
    emod_df = pd.concat(emof_subsets)
    return emod_df

def emof_cleanup(emof_df, occ_mapping, event_mapping):
    '''
    Any measurementType that is also in the Occ or Event tables must be ignored. Also drop rows
    where the measurementValue is NaN. 
    '''
        
    log.debug('   -Cleaning EMOF file...')
    mapping_list = []
    z = {**occ_mapping, **event_mapping}
    for key, value in z.items():
        mapping_list.append(key.lower())
        for item in value:
            mapping_list.append(str(item).lower())

    # Drop where measurementValue is NaN
    emof_df = emof_df.drop(emof_df[emof_df.measurementValue.isna()].index)
    # Drop where measurementType is already in Occ or Event
    emof_df = emof_df[~emof_df['measurementType'].str.lower().isin(mapping_list)]
    emof_df = emof_df.reset_index(drop=True)
    return emof_df

# %%
meta_event_mapping = {
        'eventID':['eventID'],
        'eventDate':[None],
        'parentEventID':[None],
        'decimalLatitude':['Latitude 1'],
        'decimalLongitude':['Longitude 1'],
        'institutionCode':['Originator','institutionCode','EDMO_code'],
        'datasetName':['EDMED references'],
        'maximumDepthInMeters':[None],
        'minimumDepthInMeters':[None],
        'coordinateUncertaintyInMeters':[None],
        'footprintWKT':[None], # How to put in a single value into table? Shouldn't this be metadata?
        'type':[None],
        'parenEventID':[None],
        'dataGeneralizations':[None],
        'eventRemarks':[None],
        'samplingProtocol':[None],
        'locationID':['Station name'],
        'locality':['locality','Station name','Alternative station name'],
        'locationRemarks':[None],
        }

def meta_event_gen(folder_dict):
    '''
    Grab the metadata file and create an event core file from it
    '''
    log.debug('   -Converting metafile into params dataframe...')
    meta_df =  pd.read_csv(folder_dict.get('meta_path'))
    meta_df['eventID'] = meta_df['LOCAL_CDI_ID'].str.split(pat="/").str[0]
    meta_df = create_new_columns(meta_df)
    meta_events = odv_dwc_mapping(meta_df, meta_event_mapping)
    return meta_events

# %%
def meta_emof_gen(folder_dict): 
    '''
    Convert the ODV Metadata file into an EMOF starter file. 
    Much of this is hard coded since there isn't too much semantic info 
    available on WHAT the CDI meta csv file actually means. 
    '''
    log.debug('   -Converting metafile into emof dataframe...')
    

    meta_df =  pd.read_csv(folder_dict.get('meta_path'))
    # meta_params = convert_meta_params_to_df(meta_df)

    template_meta_emofs = [{'measurementType': 'Minimum instrument depth (m)',
                          'measurementTypeID': 'https://vocab.nerc.ac.uk/collection/P01/current/MINWDIST/',
                          'measurementUnit': 'm',
                          'measurementUnitID': 'http://vocab.nerc.ac.uk/collection/P06/current/ULAA/',
                          },
                         {'measurementType': 'Maximum instrument depth (m)',
                          'measurementTypeID': 'http://vocab.nerc.ac.uk/collection/P01/current/MAXWDIST/',
                          'measurementUnit': 'm',
                          'measurementUnitID': 'http://vocab.nerc.ac.uk/collection/P06/current/ULAA/',
                          },
                         {'measurementType': 'Water depth (m)',
                          'measurementTypeID': '',
                          'measurementMethod': '', # Use Depth reference here
                          'measurementUnit': 'm',
                          'measurementUnitID': 'http://vocab.nerc.ac.uk/collection/P06/current/ULAA/',
                          },
                         {'measurementType': 'Instrument / gear type',
                          'measurementTypeID': 'http://vocab.nerc.ac.uk/collection/L05/current/',
                          'measurementUnit': 'Na',
                          'measurementUnitID': '',
                          },
                         {'measurementType': 'Platform type',
                          'measurementTypeID': 'http://vocab.nerc.ac.uk/collection/L06/current/',
                          'measurementUnit': 'Na',
                          'measurementUnitID': '',
                          }]
    template_df = pd.DataFrame(template_meta_emofs)
    in_df = meta_df

    emof_subsets = []
    for index, row in template_df.iterrows():
        measurementType = row['measurementType'] 
        df_subset = in_df[(in_df[measurementType].notna())] 

        if not df_subset.empty:
            emof_subset = df_subset.copy()
            emof_subset['eventID'] = emof_subset['LOCAL_CDI_ID'].str.split(pat="/").str[0]
            emof_subset['occurrenceID'] = None
            emof_subset['measurementID'] = None
            emof_subset['measurementTypeID'] = None
            emof_subset['measurementValue'] = emof_subset[measurementType]
            emof_subset['measurementValueID'] = None
            emof_subset['measurementMethod'] = None

            if measurementType == 'Instrument / gear type':
                gear_number = emof_subset[measurementType].str.extract(r'\((\d*?)\)')
                emof_subset['measurementTypeID'] = row['measurementTypeID'] +  gear_number

            elif measurementType == 'Platform type':
                platform_number = emof_subset[measurementType].str.extract(r'\((\d*?)\)') 
                emof_subset['measurementTypeID'] = row['measurementTypeID'] +  platform_number
                
            elif measurementType == 'Water depth (m)': 
                emof_subset['measurementMethod'] = emof_subset['Depth reference']
                

            else:
                emof_subset['measurementTypeID'] = measurementType

            emof_subset['measurementType'] = row['measurementType']
            emof_subset['measurementUnit'] = row['measurementUnit']
            emof_subset['measurementUnitID'] = row['measurementUnitID']
            emof_subset = emof_subset[['eventID',
                                       'occurrenceID',
                                       'measurementID',
                                       'measurementValue',
                                       'measurementValueID',
                                       'measurementType',
                                       'measurementTypeID',
                                       'measurementUnit',
                                       'measurementUnitID']]
            emof_subsets.append(emof_subset)
    meta_params_df = pd.concat(emof_subsets) 
    return meta_params_df

# %%
input_zip = './Datasets/'

# %%
# %%time

odv_zip = './Datasets/IFREMER: Phytoplankton/order_61216_unrestricted.zip'
odv_meta = './Datasets/IFREMER: Phytoplankton/meta.zip'

# odv_zip = './Datasets/Posidonia/order_61215_unrestricted.zip'
# odv_meta = './Datasets/Posidonia/meta.zip'

odv_zip = './Datasets/Dummy Job/61553/order_61553_unrestricted.zip'
odv_meta = './Datasets/Dummy Job/61553/meta.zip'

log.info(f'===Converting {odv_zip} to DwC===')
folder_dict = create_folder_structure(odv_zip)
unzip(folder_dict)
parsed_df, odv_list = parse_odv(folder_dict)

# Create new IDs
# ==================
log.debug('   -Building WKT...')
applied_df = parsed_df.apply(lambda row: create_wkt(row), axis='columns', result_type='expand')
applied_df = applied_df.rename(columns={0: 'CoordinateUncertaintyInMeters', 1: 'footprint_wkt'})
parsed_df  = pd.concat([parsed_df, applied_df], axis='columns')

log.debug('   -Creating Event and Occurrence IDs...')
df_id = parsed_df.apply(lambda row: create_IDs(row), axis='columns', result_type='expand')
df_id = df_id.rename(columns={0: 'eventID', 1: 'occurrenceID', 2: 'parentEventID'})
parsed_df  = pd.concat([parsed_df, df_id], axis='columns')

parsed_df = create_new_columns(parsed_df)
parsed_df = rename_odv_columns(parsed_df)
# Create EventCore File
dwc_event = odv_dwc_mapping(parsed_df, event_mapping) 
dwc_meta_event = meta_event_gen(folder_dict)
dwc_event = pd.concat([dwc_meta_event,dwc_event])
dwc_event.to_csv(folder_dict.get('event_path'), index = False)

# Create OccCore File
dwc_occ = odv_dwc_mapping(parsed_df, occ_mapping)
dwc_occ.to_csv(folder_dict.get('occ_path'), index = False)

# Create EMOF from Occ data
params = convert_params_to_df(odv_list)
event_dwc_emof = emof_gen(parsed_df, params)

# Create EMOF from Event data
meta_dwc_emof = meta_emof_gen(folder_dict)

dwc_emof = pd.concat([meta_dwc_emof,event_dwc_emof])
dwc_emof = emof_cleanup(dwc_emof, occ_mapping, event_mapping)


# Create EMOF from Meta data file


# dwc_emof.to_csv(folder_dict.get('emof_path'))

# Create Metadata File
# params = convert_params_to_df()
# dwc_occ = <some function>
# dwc_emof.to_json(folder_dict.get('meta_path'))

# Dump all data
# parsed_df.to_csv(folder_dict.get('all_data_path'), index = False)

log.info(f'===Finished converting {odv_zip} to DwC===')
dwc_emof
# Out:
# DEBUG:main:===== Datasets/Dummy Job/61553/unzip/000729_BODV_Bent_139979_V1.txt =====
# DEBUG:main:===== Datasets/Dummy Job/61553/unzip/000729_BODV_Bent_131889_V1.txt =====
# DEBUG:main:===== Datasets/Dummy Job/61553/unzip/000729_BODV_Bent_130719_V1.txt =====
# DEBUG:main:===== Datasets/Dummy Job/61553/unzip/000729_BODV_Bent_138682_V1.txt =====
# DEBUG:main:===== Datasets/Dummy Job/61553/unzip/000729_BODV_Bent_133712_V1.txt =====
# DEBUG:main:===== Datasets/Dummy Job/61553/unzip/000729_BODV_Bent_138895_V1.txt =====
# DEBUG:main:===== Datasets/Dummy Job/61553/unzip/000729_BODV_Bent_131959_V1.txt =====
# DEBUG:main:===== Datasets/Dummy Job/61553/unzip/000729_BODV_Bent_139415_V1.txt =====
# DEBUG:main:===== Datasets/Dummy Job/61553/unzip/000000_README.txt =====
# DEBUG:main:list index out of range
# DEBUG:main:===== Datasets/Dummy Job/61553/unzip/order_61553_unrestricted.csv =====
# DEBUG:main:list index out of range
# DEBUG:main:===== Datasets/Dummy Job/61553/unzip/000729_BODV_Bent_137951_V1.txt =====
# DEBUG:main:Reading metadata file: Datasets/Dummy Job/61553/unzip/order_61553_unrestricted.csv...
# DEBUG:main:   -Building WKT...
# DEBUG:main:   -Creating Event and Occurrence IDs...
# DEBUG:main:   -Renaming ODV column names...
# DEBUG:main:   -Mapping column names...
# DEBUG:main:KeyError: Changing Samplingprotocol column to samplingProtocol but failed.
# DEBUG:main:KeyError: Changing SamplingProtocol column to samplingProtocol but failed.
# DEBUG:main:   -Converting metafile into params dataframe...
# DEBUG:main:   -Mapping column names...
# DEBUG:main:   -Mapping column names...
# DEBUG:main:   -Converting ODV params to dataframe...
# DEBUG:main:   -Downloading vocab from NERC
# DEBUG:main:   -Downloading vocab from NERC
# DEBUG:main:   -Downloading vocab from NERC
# DEBUG:main:   -Downloading vocab from NERC
# DEBUG:main:   -Downloading vocab from NERC
# DEBUG:main:   -Generating EMOF file...
# DEBUG:main:   -Converting metafile into emof dataframe...
# DEBUG:main:   -Cleaning EMOF file...
# INFO:main:===Finished converting ./Datasets/Dummy Job/61553/order_61553_unrestricted.zip to DwC===
# CPU times: user 581 ms, sys: 30.3 ms, total: 611 ms
# Wall time: 2.95 s
#                                            eventID      occurrenceID  \
# 0                                      Bent_130719              None
# 1                                      Bent_131959              None
# 2                                      Bent_137951              None
# 3                                      Bent_138641              None
# 4                                      Bent_138682              None
# ...                                            ...               ...
# 2198  Bent_137951_JUVD0011_2002-09-09T00:00:00.000  28448_nan_129868
# 2199  Bent_137951_JUVD0011_2002-09-09T00:00:00.000    28446_nan_2040
# 2200  Bent_137951_JUVD0011_2002-09-09T00:00:00.000    28448_nan_2040
# 2201  Bent_137951_JUVD0011_2002-09-09T00:00:00.000  28444_nan_107381
# 2202  Bent_137951_JUVD0011_2002-09-09T00:00:00.000  28448_nan_107381
#
#                              measurementID measurementValue  \
# 0                                     None              0.4
# 1                                     None              0.3
# 2                                     None         0.341358
# 3                                     None             1.18
# 4                                     None             1.02
# ...                                    ...              ...
# 2198  21732528-17b0-4ee3-bf24-99a3556dbf42           0.0193
# 2199  e7472aa3-8c7b-4164-931b-516378a47fe6           0.0006
# 2200  f92d9690-ee0f-4d74-ad22-7cb6a3992a7c           0.0002
# 2201  e2e5ed6f-28eb-434f-a2ba-a584602abe58           0.0045
# 2202  e8cdf929-4e9e-4f78-ab24-73fdf0583810           0.0297
#
#      measurementValueID       measurementType  \
# 0                  None       Water depth (m)
# 1                  None       Water depth (m)
# 2                  None       Water depth (m)
# 3                  None       Water depth (m)
# 4                  None       Water depth (m)
# ...                 ...                   ...
# 2198               None  DWBiom_Samp_BE007117
# 2199               None  DWBiom_Samp_BE007117
# 2200               None  DWBiom_Samp_BE007117
# 2201               None  DWBiom_Samp_BE007117
# 2202               None  DWBiom_Samp_BE007117
#
#                                               measurementTypeID  \
# 0                                                          None
# 1                                                          None
# 2                                                          None
# 3                                                          None
# 4                                                          None
# ...                                                         ...
# 2198  https://vocab.nerc.ac.uk/collection/P01/current/ODRYBM01/
# 2199  https://vocab.nerc.ac.uk/collection/P01/current/ODRYBM01/
# 2200  https://vocab.nerc.ac.uk/collection/P01/current/ODRYBM01/
# 2201  https://vocab.nerc.ac.uk/collection/P01/current/ODRYBM01/
# 2202  https://vocab.nerc.ac.uk/collection/P01/current/ODRYBM01/
#
#      measurementUnit                                      measurementUnitID  \
# 0                  m   http://vocab.nerc.ac.uk/collection/P06/current/ULAA/
# 1                  m   http://vocab.nerc.ac.uk/collection/P06/current/ULAA/
# 2                  m   http://vocab.nerc.ac.uk/collection/P06/current/ULAA/
# 3                  m   http://vocab.nerc.ac.uk/collection/P06/current/ULAA/
# 4                  m   http://vocab.nerc.ac.uk/collection/P06/current/ULAA/
# ...              ...                                                    ...
# 2198               g  https://vocab.nerc.ac.uk/collection/P06/current/UGRM/
# 2199               g  https://vocab.nerc.ac.uk/collection/P06/current/UGRM/
# 2200               g  https://vocab.nerc.ac.uk/collection/P06/current/UGRM/
# 2201               g  https://vocab.nerc.ac.uk/collection/P06/current/UGRM/
# 2202               g  https://vocab.nerc.ac.uk/collection/P06/current/UGRM/
#
#      parentEventID
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# ...            ...
# 2198   Bent_137951
# 2199   Bent_137951
# 2200   Bent_137951
# 2201   Bent_137951
# 2202   Bent_137951
#
# [2203 rows x 10 columns]

# %%
parsed_df
# Out:
#       Station   Cruise  EDMO_code  Bot. Depth  yyyy-mm-ddThh:mm:ss.sss  \
# 0    LISD0022  unknown      729.0         NaN  1992-04-07T00:00:00.000
# 1    LISD0022  unknown      729.0         NaN  1992-04-07T00:00:00.000
# 2    LISD0022  unknown      729.0         NaN  1992-04-07T00:00:00.000
# 3    LISD0022  unknown      729.0         NaN  1992-04-07T00:00:00.000
# 4    LISD0022  unknown      729.0         NaN  1992-04-07T00:00:00.000
# ..        ...      ...        ...         ...                      ...
# 373  JUVD0011  unknown      729.0         NaN  2002-09-09T00:00:00.000
# 374  JUVD0011  unknown      729.0         NaN  2002-09-09T00:00:00.000
# 375  JUVD0011  unknown      729.0         NaN  2002-09-09T00:00:00.000
# 376  JUVD0011  unknown      729.0         NaN  2002-09-09T00:00:00.000
# 377  JUVD0011  unknown      729.0         NaN  2002-09-09T00:00:00.000
#
#      Latitude Type  Longitude LOCAL_CDI_ID  MinimumObservationDepth  \
# 0     55.0936    *     8.5615  Bent_138641                      0.0
# 1     55.0936    *     8.5615  Bent_138641                      0.0
# 2     55.0936    *     8.5615  Bent_138641                      0.0
# 3     55.0936    *     8.5615  Bent_138641                      0.0
# 4     55.0936    *     8.5615  Bent_138641                      0.0
# ..        ...  ...        ...          ...                      ...
# 373   55.1826    *     8.5902  Bent_137951                      0.0
# 374   55.1826    *     8.5902  Bent_137951                      0.0
# 375   55.1826    *     8.5902  Bent_137951                      0.0
# 376   55.1826    *     8.5902  Bent_137951                      0.0
# 377   55.1826    *     8.5902  Bent_137951                      0.0
#
#      MaximumObservationDepth  SampleID  SamplingEffort  SubsampleID  \
# 0                        0.0     30653          0.0395          NaN
# 1                        0.0     30653          0.0395          NaN
# 2                        0.0     30653          0.0395          NaN
# 3                        0.0     30653          0.0395          NaN
# 4                        0.0     30653          0.0395          NaN
# ..                       ...       ...             ...          ...
# 373                      0.0     28448          0.0079          NaN
# 374                      0.0     28446          0.0079          NaN
# 375                      0.0     28448          0.0079          NaN
# 376                      0.0     28444          0.0079          NaN
# 377                      0.0     28448          0.0079          NaN
#
#      SubSamplingCoefficient        ScientificName  \
# 0                       NaN          Hydrobia sp.
# 1                       NaN       Macoma balthica
# 2                       NaN     Phyllodoce mucosa
# 3                       NaN     Scoloplos armiger
# 4                       NaN  Tubificoides benedii
# ..                      ...                   ...
# 373                     NaN      Arenicola marina
# 374                     NaN    Tubificidae indet.
# 375                     NaN    Tubificidae indet.
# 376                     NaN       Carcinus maenas
# 377                     NaN       Carcinus maenas
#
#                               ScientificNameID Sex LifeStage  \
# 0    urn:lsid:marinespecies.org:taxname:138081   U         U
# 1    urn:lsid:marinespecies.org:taxname:141579   U         U
# 2    urn:lsid:marinespecies.org:taxname:334512   U         U
# 3    urn:lsid:marinespecies.org:taxname:334772   U         U
# 4    urn:lsid:marinespecies.org:taxname:137571   U         U
# ..                                         ...  ..       ...
# 373  urn:lsid:marinespecies.org:taxname:129868   U         U
# 374    urn:lsid:marinespecies.org:taxname:2040   U         U
# 375    urn:lsid:marinespecies.org:taxname:2040   U         U
# 376  urn:lsid:marinespecies.org:taxname:107381   U         U
# 377  urn:lsid:marinespecies.org:taxname:107381   U         U
#
#      ObservedIndividualCount  WWBiom_Samp_BE007117  DWBiom_Samp_BE007117  \
# 0                     1255.0                   NaN                   NaN
# 1                       13.0                   NaN                0.3958
# 2                        2.0                   NaN                   NaN
# 3                        8.0                   NaN                0.0092
# 4                        5.0                   NaN                   NaN
# ..                       ...                   ...                   ...
# 373                      2.0                   NaN                0.0193
# 374                      2.0                   NaN                0.0006
# 375                      1.0                   NaN                0.0002
# 376                      1.0                   NaN                0.0045
# 377                      2.0                   NaN                0.0297
#
#            scope                                                  defined_by  \
# 0    Bent_138641  https://cdi.seadatanet.org/report/edmo/729/Bent_138641/xml
# 1    Bent_138641  https://cdi.seadatanet.org/report/edmo/729/Bent_138641/xml
# 2    Bent_138641  https://cdi.seadatanet.org/report/edmo/729/Bent_138641/xml
# 3    Bent_138641  https://cdi.seadatanet.org/report/edmo/729/Bent_138641/xml
# 4    Bent_138641  https://cdi.seadatanet.org/report/edmo/729/Bent_138641/xml
# ..           ...                                                         ...
# 373  Bent_137951  https://cdi.seadatanet.org/report/edmo/729/Bent_137951/xml
# 374  Bent_137951  https://cdi.seadatanet.org/report/edmo/729/Bent_137951/xml
# 375  Bent_137951  https://cdi.seadatanet.org/report/edmo/729/Bent_137951/xml
# 376  Bent_137951  https://cdi.seadatanet.org/report/edmo/729/Bent_137951/xml
# 377  Bent_137951  https://cdi.seadatanet.org/report/edmo/729/Bent_137951/xml
#
#          Data Set name  \
# 0    Benthosset_138641
# 1    Benthosset_138641
# 2    Benthosset_138641
# 3    Benthosset_138641
# 4    Benthosset_138641
# ..                 ...
# 373  Benthosset_137951
# 374  Benthosset_137951
# 375  Benthosset_137951
# 376  Benthosset_137951
# 377  Benthosset_137951
#
#                                                                                                        Discipline  \
# 0    Biological oceanography (DS01)|Marine geology (DS04)|Administration and dimensions (DS07)|Terrestrial (DS08)
# 1    Biological oceanography (DS01)|Marine geology (DS04)|Administration and dimensions (DS07)|Terrestrial (DS08)
# 2    Biological oceanography (DS01)|Marine geology (DS04)|Administration and dimensions (DS07)|Terrestrial (DS08)
# 3    Biological oceanography (DS01)|Marine geology (DS04)|Administration and dimensions (DS07)|Terrestrial (DS08)
# 4    Biological oceanography (DS01)|Marine geology (DS04)|Administration and dimensions (DS07)|Terrestrial (DS08)
# ..                                                                                                            ...
# 373  Biological oceanography (DS01)|Marine geology (DS04)|Administration and dimensions (DS07)|Terrestrial (DS08)
# 374  Biological oceanography (DS01)|Marine geology (DS04)|Administration and dimensions (DS07)|Terrestrial (DS08)
# 375  Biological oceanography (DS01)|Marine geology (DS04)|Administration and dimensions (DS07)|Terrestrial (DS08)
# 376  Biological oceanography (DS01)|Marine geology (DS04)|Administration and dimensions (DS07)|Terrestrial (DS08)
# 377  Biological oceanography (DS01)|Marine geology (DS04)|Administration and dimensions (DS07)|Terrestrial (DS08)
#
#                                                                                                      Category  \
# 0    Other biological measurements (B027)|Rock and sediment biota (G055)|Administration and dimensions (Z005)
# 1    Other biological measurements (B027)|Rock and sediment biota (G055)|Administration and dimensions (Z005)
# 2    Other biological measurements (B027)|Rock and sediment biota (G055)|Administration and dimensions (Z005)
# 3    Other biological measurements (B027)|Rock and sediment biota (G055)|Administration and dimensions (Z005)
# 4    Other biological measurements (B027)|Rock and sediment biota (G055)|Administration and dimensions (Z005)
# ..                                                                                                        ...
# 373  Other biological measurements (B027)|Rock and sediment biota (G055)|Administration and dimensions (Z005)
# 374  Other biological measurements (B027)|Rock and sediment biota (G055)|Administration and dimensions (Z005)
# 375  Other biological measurements (B027)|Rock and sediment biota (G055)|Administration and dimensions (Z005)
# 376  Other biological measurements (B027)|Rock and sediment biota (G055)|Administration and dimensions (Z005)
# 377  Other biological measurements (B027)|Rock and sediment biota (G055)|Administration and dimensions (Z005)
#
#                                                                                                                                                                           Variables measured  \
# 0    Reference numbers (ACYC)|Sampling parameters (SAMP)|SeaDataNet biological format biotic parameters (BPRP)|Vertical spatial coordinates (AHGT)|Zoobenthos taxonomy-related counts (ZOOB)
# 1    Reference numbers (ACYC)|Sampling parameters (SAMP)|SeaDataNet biological format biotic parameters (BPRP)|Vertical spatial coordinates (AHGT)|Zoobenthos taxonomy-related counts (ZOOB)
# 2    Reference numbers (ACYC)|Sampling parameters (SAMP)|SeaDataNet biological format biotic parameters (BPRP)|Vertical spatial coordinates (AHGT)|Zoobenthos taxonomy-related counts (ZOOB)
# 3    Reference numbers (ACYC)|Sampling parameters (SAMP)|SeaDataNet biological format biotic parameters (BPRP)|Vertical spatial coordinates (AHGT)|Zoobenthos taxonomy-related counts (ZOOB)
# 4    Reference numbers (ACYC)|Sampling parameters (SAMP)|SeaDataNet biological format biotic parameters (BPRP)|Vertical spatial coordinates (AHGT)|Zoobenthos taxonomy-related counts (ZOOB)
# ..                                                                                                                                                                                       ...
# 373  Reference numbers (ACYC)|Sampling parameters (SAMP)|SeaDataNet biological format biotic parameters (BPRP)|Vertical spatial coordinates (AHGT)|Zoobenthos taxonomy-related counts (ZOOB)
# 374  Reference numbers (ACYC)|Sampling parameters (SAMP)|SeaDataNet biological format biotic parameters (BPRP)|Vertical spatial coordinates (AHGT)|Zoobenthos taxonomy-related counts (ZOOB)
# 375  Reference numbers (ACYC)|Sampling parameters (SAMP)|SeaDataNet biological format biotic parameters (BPRP)|Vertical spatial coordinates (AHGT)|Zoobenthos taxonomy-related counts (ZOOB)
# 376  Reference numbers (ACYC)|Sampling parameters (SAMP)|SeaDataNet biological format biotic parameters (BPRP)|Vertical spatial coordinates (AHGT)|Zoobenthos taxonomy-related counts (ZOOB)
# 377  Reference numbers (ACYC)|Sampling parameters (SAMP)|SeaDataNet biological format biotic parameters (BPRP)|Vertical spatial coordinates (AHGT)|Zoobenthos taxonomy-related counts (ZOOB)
#
#     Data format  Data format version  Data size  Data Set creation Date  \
# 0          bodv                  NaN        NaN                20220405
# 1          bodv                  NaN        NaN                20220405
# 2          bodv                  NaN        NaN                20220405
# 3          bodv                  NaN        NaN                20220405
# 4          bodv                  NaN        NaN                20220405
# ..          ...                  ...        ...                     ...
# 373        bodv                  NaN        NaN                20220405
# 374        bodv                  NaN        NaN                20220405
# 375        bodv                  NaN        NaN                20220405
# 376        bodv                  NaN        NaN                20220405
# 377        bodv                  NaN        NaN                20220405
#
#      Latitude 1  Latitude 2  Longitude 1  Longitude 2  \
# 0      8.561500    8.561501    55.093597    55.093601
# 1      8.561500    8.561501    55.093597    55.093601
# 2      8.561500    8.561501    55.093597    55.093601
# 3      8.561500    8.561501    55.093597    55.093601
# 4      8.561500    8.561501    55.093597    55.093601
# ..          ...         ...          ...          ...
# 373    8.590199    8.590200    55.182598    55.182602
# 374    8.590199    8.590200    55.182598    55.182602
# 375    8.590199    8.590200    55.182598    55.182602
# 376    8.590199    8.590200    55.182598    55.182602
# 377    8.590199    8.590200    55.182598    55.182602
#
#                                Datum Measuring area type  Water depth (m)  \
# 0    World Geodetic System 84 (4326)         point (004)         1.180000
# 1    World Geodetic System 84 (4326)         point (004)         1.180000
# 2    World Geodetic System 84 (4326)         point (004)         1.180000
# 3    World Geodetic System 84 (4326)         point (004)         1.180000
# 4    World Geodetic System 84 (4326)         point (004)         1.180000
# ..                               ...                 ...              ...
# 373  World Geodetic System 84 (4326)         point (004)         0.341358
# 374  World Geodetic System 84 (4326)         point (004)         0.341358
# 375  World Geodetic System 84 (4326)         point (004)         0.341358
# 376  World Geodetic System 84 (4326)         point (004)         0.341358
# 377  World Geodetic System 84 (4326)         point (004)         0.341358
#
#                     Depth reference  Minimum instrument depth (m)  \
# 0    Lowest Astronomical Tide (D01)                           NaN
# 1    Lowest Astronomical Tide (D01)                           NaN
# 2    Lowest Astronomical Tide (D01)                           NaN
# 3    Lowest Astronomical Tide (D01)                           NaN
# 4    Lowest Astronomical Tide (D01)                           NaN
# ..                              ...                           ...
# 373  Lowest Astronomical Tide (D01)                           NaN
# 374  Lowest Astronomical Tide (D01)                           NaN
# 375  Lowest Astronomical Tide (D01)                           NaN
# 376  Lowest Astronomical Tide (D01)                           NaN
# 377  Lowest Astronomical Tide (D01)                           NaN
#
#      Maximum instrument depth (m)  Start Date Start time  End Date  End time  \
# 0                             NaN    19920407   00:00:00  19920407  00:00:00
# 1                             NaN    19920407   00:00:00  19920407  00:00:00
# 2                             NaN    19920407   00:00:00  19920407  00:00:00
# 3                             NaN    19920407   00:00:00  19920407  00:00:00
# 4                             NaN    19920407   00:00:00  19920407  00:00:00
# ..                            ...         ...        ...       ...       ...
# 373                           NaN    20020909   00:00:00  20020909  00:00:00
# 374                           NaN    20020909   00:00:00  20020909  00:00:00
# 375                           NaN    20020909   00:00:00  20020909  00:00:00
# 376                           NaN    20020909   00:00:00  20020909  00:00:00
# 377                           NaN    20020909   00:00:00  20020909  00:00:00
#
#      Vertical resolution  Vertical resolution unit Instrument / gear type  \
# 0                    NaN                       NaN  benthos samplers (24)
# 1                    NaN                       NaN  benthos samplers (24)
# 2                    NaN                       NaN  benthos samplers (24)
# 3                    NaN                       NaN  benthos samplers (24)
# 4                    NaN                       NaN  benthos samplers (24)
# ..                   ...                       ...                    ...
# 373                  NaN                       NaN  benthos samplers (24)
# 374                  NaN                       NaN  benthos samplers (24)
# 375                  NaN                       NaN  benthos samplers (24)
# 376                  NaN                       NaN  benthos samplers (24)
# 377                  NaN                       NaN  benthos samplers (24)
#
#      Track resolution  Track resolution unit  Frequency  Frequency unit  \
# 0                 NaN                    NaN        NaN             NaN
# 1                 NaN                    NaN        NaN             NaN
# 2                 NaN                    NaN        NaN             NaN
# 3                 NaN                    NaN        NaN             NaN
# 4                 NaN                    NaN        NaN             NaN
# ..                ...                    ...        ...             ...
# 373               NaN                    NaN        NaN             NaN
# 374               NaN                    NaN        NaN             NaN
# 375               NaN                    NaN        NaN             NaN
# 376               NaN                    NaN        NaN             NaN
# 377               NaN                    NaN        NaN             NaN
#
#             Platform type  Cruise name  Alternative cruise name  \
# 0    research vessel (31)          NaN                      NaN
# 1    research vessel (31)          NaN                      NaN
# 2    research vessel (31)          NaN                      NaN
# 3    research vessel (31)          NaN                      NaN
# 4    research vessel (31)          NaN                      NaN
# ..                    ...          ...                      ...
# 373  research vessel (31)          NaN                      NaN
# 374  research vessel (31)          NaN                      NaN
# 375  research vessel (31)          NaN                      NaN
# 376  research vessel (31)          NaN                      NaN
# 377  research vessel (31)          NaN                      NaN
#
#      Cruise start Date Station name Alternative station name  \
# 0                  NaN     LISD0022                 LISD0022
# 1                  NaN     LISD0022                 LISD0022
# 2                  NaN     LISD0022                 LISD0022
# 3                  NaN     LISD0022                 LISD0022
# 4                  NaN     LISD0022                 LISD0022
# ..                 ...          ...                      ...
# 373                NaN     JUVD0011                 JUVD0011
# 374                NaN     JUVD0011                 JUVD0011
# 375                NaN     JUVD0011                 JUVD0011
# 376                NaN     JUVD0011                 JUVD0011
# 377                NaN     JUVD0011                 JUVD0011
#
#      Station start Date  \
# 0              19820425
# 1              19820425
# 2              19820425
# 3              19820425
# 4              19820425
# ..                  ...
# 373            19800917
# 374            19800917
# 375            19800917
# 376            19800917
# 377            19800917
#
#                                                                      Originator  \
# 0    Aarhus University, Department of Bioscience, Marine Ecology Roskilde (729)
# 1    Aarhus University, Department of Bioscience, Marine Ecology Roskilde (729)
# 2    Aarhus University, Department of Bioscience, Marine Ecology Roskilde (729)
# 3    Aarhus University, Department of Bioscience, Marine Ecology Roskilde (729)
# 4    Aarhus University, Department of Bioscience, Marine Ecology Roskilde (729)
# ..                                                                          ...
# 373  Aarhus University, Department of Bioscience, Marine Ecology Roskilde (729)
# 374  Aarhus University, Department of Bioscience, Marine Ecology Roskilde (729)
# 375  Aarhus University, Department of Bioscience, Marine Ecology Roskilde (729)
# 376  Aarhus University, Department of Bioscience, Marine Ecology Roskilde (729)
# 377  Aarhus University, Department of Bioscience, Marine Ecology Roskilde (729)
#
#                                                             Data Holding centre  \
# 0    Aarhus University, Department of Bioscience, Marine Ecology Roskilde (729)
# 1    Aarhus University, Department of Bioscience, Marine Ecology Roskilde (729)
# 2    Aarhus University, Department of Bioscience, Marine Ecology Roskilde (729)
# 3    Aarhus University, Department of Bioscience, Marine Ecology Roskilde (729)
# 4    Aarhus University, Department of Bioscience, Marine Ecology Roskilde (729)
# ..                                                                          ...
# 373  Aarhus University, Department of Bioscience, Marine Ecology Roskilde (729)
# 374  Aarhus University, Department of Bioscience, Marine Ecology Roskilde (729)
# 375  Aarhus University, Department of Bioscience, Marine Ecology Roskilde (729)
# 376  Aarhus University, Department of Bioscience, Marine Ecology Roskilde (729)
# 377  Aarhus University, Department of Bioscience, Marine Ecology Roskilde (729)
#
#      Project name  Project type  \
# 0             NaN           NaN
# 1             NaN           NaN
# 2             NaN           NaN
# 3             NaN           NaN
# 4             NaN           NaN
# ..            ...           ...
# 373           NaN           NaN
# 374           NaN           NaN
# 375           NaN           NaN
# 376           NaN           NaN
# 377           NaN           NaN
#
#                                                      EDMED references  \
# 0    Time series of zoobenthos in Danish waters (1979 onwards) (1118)
# 1    Time series of zoobenthos in Danish waters (1979 onwards) (1118)
# 2    Time series of zoobenthos in Danish waters (1979 onwards) (1118)
# 3    Time series of zoobenthos in Danish waters (1979 onwards) (1118)
# 4    Time series of zoobenthos in Danish waters (1979 onwards) (1118)
# ..                                                                ...
# 373  Time series of zoobenthos in Danish waters (1979 onwards) (1118)
# 374  Time series of zoobenthos in Danish waters (1979 onwards) (1118)
# 375  Time series of zoobenthos in Danish waters (1979 onwards) (1118)
# 376  Time series of zoobenthos in Danish waters (1979 onwards) (1118)
# 377  Time series of zoobenthos in Danish waters (1979 onwards) (1118)
#
#      CSR references  CSR platform name  CSR platform code  \
# 0               NaN                NaN                NaN
# 1               NaN                NaN                NaN
# 2               NaN                NaN                NaN
# 3               NaN                NaN                NaN
# 4               NaN                NaN                NaN
# ..              ...                ...                ...
# 373             NaN                NaN                NaN
# 374             NaN                NaN                NaN
# 375             NaN                NaN                NaN
# 376             NaN                NaN                NaN
# 377             NaN                NaN                NaN
#
#      Publication references  \
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
# ..                      ...
# 373                     NaN
# 374                     NaN
# 375                     NaN
# 376                     NaN
# 377                     NaN
#
#                                                       Data Distributor  \
# 0    Aarhus University,Danish Centre for Environment and Energy (3037)
# 1    Aarhus University,Danish Centre for Environment and Energy (3037)
# 2    Aarhus University,Danish Centre for Environment and Energy (3037)
# 3    Aarhus University,Danish Centre for Environment and Energy (3037)
# 4    Aarhus University,Danish Centre for Environment and Energy (3037)
# ..                                                                 ...
# 373  Aarhus University,Danish Centre for Environment and Energy (3037)
# 374  Aarhus University,Danish Centre for Environment and Energy (3037)
# 375  Aarhus University,Danish Centre for Environment and Energy (3037)
# 376  Aarhus University,Danish Centre for Environment and Energy (3037)
# 377  Aarhus University,Danish Centre for Environment and Energy (3037)
#
#      Database reference            Access/ordering of data  \
# 0                   NaN  web data access with registration
# 1                   NaN  web data access with registration
# 2                   NaN  web data access with registration
# 3                   NaN  web data access with registration
# 4                   NaN  web data access with registration
# ..                  ...                                ...
# 373                 NaN  web data access with registration
# 374                 NaN  web data access with registration
# 375                 NaN  web data access with registration
# 376                 NaN  web data access with registration
# 377                 NaN  web data access with registration
#
#                                       Access restriction  \
# 0    Creative Commons Attribution 4.0 International (CB)
# 1    Creative Commons Attribution 4.0 International (CB)
# 2    Creative Commons Attribution 4.0 International (CB)
# 3    Creative Commons Attribution 4.0 International (CB)
# 4    Creative Commons Attribution 4.0 International (CB)
# ..                                                   ...
# 373  Creative Commons Attribution 4.0 International (CB)
# 374  Creative Commons Attribution 4.0 International (CB)
# 375  Creative Commons Attribution 4.0 International (CB)
# 376  Creative Commons Attribution 4.0 International (CB)
# 377  Creative Commons Attribution 4.0 International (CB)
#
#      CDI-record creation date  CDI-record id LOCAL_CDI_ID_meta  \
# 0                    20220405        2049366    Bent_138641/v1
# 1                    20220405        2049366    Bent_138641/v1
# 2                    20220405        2049366    Bent_138641/v1
# 3                    20220405        2049366    Bent_138641/v1
# 4                    20220405        2049366    Bent_138641/v1
# ..                        ...            ...               ...
# 373                  20220405        2049316    Bent_137951/v1
# 374                  20220405        2049316    Bent_137951/v1
# 375                  20220405        2049316    Bent_137951/v1
# 376                  20220405        2049316    Bent_137951/v1
# 377                  20220405        2049316    Bent_137951/v1
#
#                                                                     CDI-partner  \
# 0    Aarhus University, Department of Bioscience, Marine Ecology Roskilde (729)
# 1    Aarhus University, Department of Bioscience, Marine Ecology Roskilde (729)
# 2    Aarhus University, Department of Bioscience, Marine Ecology Roskilde (729)
# 3    Aarhus University, Department of Bioscience, Marine Ecology Roskilde (729)
# 4    Aarhus University, Department of Bioscience, Marine Ecology Roskilde (729)
# ..                                                                          ...
# 373  Aarhus University, Department of Bioscience, Marine Ecology Roskilde (729)
# 374  Aarhus University, Department of Bioscience, Marine Ecology Roskilde (729)
# 375  Aarhus University, Department of Bioscience, Marine Ecology Roskilde (729)
# 376  Aarhus University, Department of Bioscience, Marine Ecology Roskilde (729)
# 377  Aarhus University, Department of Bioscience, Marine Ecology Roskilde (729)
#
#      CoordinateUncertaintyInMeters  \
# 0                         0.214508
# 1                         0.214508
# 2                         0.214508
# 3                         0.214508
# 4                         0.214508
# ..                             ...
# 373                       0.214501
# 374                       0.214501
# 375                       0.214501
# 376                       0.214501
# 377                       0.214501
#
#                                                                                                                                               footprint_wkt  \
# 0    POLYGON ((55.0935974121 8.5614995956, 55.0935974121 8.5615005493, 55.0936012268 8.5615005493, 55.0936012268 8.5614995956, 55.0935974121 8.5614995956))
# 1    POLYGON ((55.0935974121 8.5614995956, 55.0935974121 8.5615005493, 55.0936012268 8.5615005493, 55.0936012268 8.5614995956, 55.0935974121 8.5614995956))
# 2    POLYGON ((55.0935974121 8.5614995956, 55.0935974121 8.5615005493, 55.0936012268 8.5615005493, 55.0936012268 8.5614995956, 55.0935974121 8.5614995956))
# 3    POLYGON ((55.0935974121 8.5614995956, 55.0935974121 8.5615005493, 55.0936012268 8.5615005493, 55.0936012268 8.5614995956, 55.0935974121 8.5614995956))
# 4    POLYGON ((55.0935974121 8.5614995956, 55.0935974121 8.5615005493, 55.0936012268 8.5615005493, 55.0936012268 8.5614995956, 55.0935974121 8.5614995956))
# ..                                                                                                                                                      ...
# 373     POLYGON ((55.182598114 8.5901994705, 55.182598114 8.5902004242, 55.1826019287 8.5902004242, 55.1826019287 8.5901994705, 55.182598114 8.5901994705))
# 374     POLYGON ((55.182598114 8.5901994705, 55.182598114 8.5902004242, 55.1826019287 8.5902004242, 55.1826019287 8.5901994705, 55.182598114 8.5901994705))
# 375     POLYGON ((55.182598114 8.5901994705, 55.182598114 8.5902004242, 55.1826019287 8.5902004242, 55.1826019287 8.5901994705, 55.182598114 8.5901994705))
# 376     POLYGON ((55.182598114 8.5901994705, 55.182598114 8.5902004242, 55.1826019287 8.5902004242, 55.1826019287 8.5901994705, 55.182598114 8.5901994705))
# 377     POLYGON ((55.182598114 8.5901994705, 55.182598114 8.5902004242, 55.1826019287 8.5902004242, 55.1826019287 8.5901994705, 55.182598114 8.5901994705))
#
#                                           eventID      occurrenceID  \
# 0    Bent_138641_LISD0022_1992-04-07T00:00:00.000  30653_nan_138081
# 1    Bent_138641_LISD0022_1992-04-07T00:00:00.000  30653_nan_141579
# 2    Bent_138641_LISD0022_1992-04-07T00:00:00.000  30653_nan_334512
# 3    Bent_138641_LISD0022_1992-04-07T00:00:00.000  30653_nan_334772
# 4    Bent_138641_LISD0022_1992-04-07T00:00:00.000  30653_nan_137571
# ..                                            ...               ...
# 373  Bent_137951_JUVD0011_2002-09-09T00:00:00.000  28448_nan_129868
# 374  Bent_137951_JUVD0011_2002-09-09T00:00:00.000    28446_nan_2040
# 375  Bent_137951_JUVD0011_2002-09-09T00:00:00.000    28448_nan_2040
# 376  Bent_137951_JUVD0011_2002-09-09T00:00:00.000  28444_nan_107381
# 377  Bent_137951_JUVD0011_2002-09-09T00:00:00.000  28448_nan_107381
#
#     parentEventID occurrenceStatus   basisOfRecord institutionCode  \
# 0     Bent_138641          present  MaterialSample      EDMO:729.0
# 1     Bent_138641          present  MaterialSample      EDMO:729.0
# 2     Bent_138641          present  MaterialSample      EDMO:729.0
# 3     Bent_138641          present  MaterialSample      EDMO:729.0
# 4     Bent_138641          present  MaterialSample      EDMO:729.0
# ..            ...              ...             ...             ...
# 373   Bent_137951          present  MaterialSample      EDMO:729.0
# 374   Bent_137951          present  MaterialSample      EDMO:729.0
# 375   Bent_137951          present  MaterialSample      EDMO:729.0
# 376   Bent_137951          present  MaterialSample      EDMO:729.0
# 377   Bent_137951          present  MaterialSample      EDMO:729.0
#
#               locality
# 0    LISD0022_LISD0022
# 1    LISD0022_LISD0022
# 2    LISD0022_LISD0022
# 3    LISD0022_LISD0022
# 4    LISD0022_LISD0022
# ..                 ...
# 373  JUVD0011_JUVD0011
# 374  JUVD0011_JUVD0011
# 375  JUVD0011_JUVD0011
# 376  JUVD0011_JUVD0011
# 377  JUVD0011_JUVD0011
#
# [378 rows x 86 columns]

# %%
event_dwc_emof = emof_gen(parsed_df, params)
# Out:
# DEBUG:main:   -Generating EMOF file...

# %%
'sdf' in dwc_emof.iloc[1].index
# Out:
# False
